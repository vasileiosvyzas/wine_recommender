# %% [markdown]
# # Extracting wine flavours
# In this notebook we are extracting each individual flavour from the wine descriptions and we are implementing a co-occurence matrix to figure out which flavours go together.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import nltk
import re
import pickle
import spacy
import en_core_web_sm

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem.porter import *
from collections import Counter
from nltk import word_tokenize
from nltk import sent_tokenize
from sklearn.metrics.pairwise import cosine_similarity

nlp = en_core_web_sm.load()
# %matplotlib inline

# %%
os.chdir('/home/fykos/Documents/workspace/wine_recommendation_system//')

# %%
wine = pd.read_csv('data/raw/winemag-data-130k-v2.csv')

# %% [markdown]
# # Extracting the flavours from the descriptions
# Here I will use spacy to extract all the nouns and noun phrases which is the type of the fruit flavours and I will filter this list better with another list I have from external sources.

# %%
def normalize(review):
    review_letters = re.sub('[^a-zA-Z]', ' ', str(review))
    review_letters = review_letters.lower()
    return (" ".join(review_letters.split()))

# %%
def remove_stopwords(review):
    stop_words = set(stopwords.words('english'))
    ls = [word for word in review.split() if word not in stop_words]
    txt = " ".join(ls)
    return (txt)

# %%
def noun_finder(review):
    blob = nlp(normalize(review))
    return (" ".join([token.text for token in blob if token.tag_ == 'NN']))

# %%
noun_list = wine['description'].map(noun_finder).values

# %%
stops = ['wine', 'pasta', 'whole', 'character', 'cabernet', 'wood', 'spicy', 'tannins', 'crisp', 'juicy', 'fruits', 'blend', 'sauvignon', 'structure', 'fruity', 'aromas', 'flavors', 'ripe', 'syrup', 'cake', 'cheese', 'cream', 'bean', 'hard', 'milk', 'sauce', 'barbecue', 'steak', 'rock', 'powder', 'ruby', 'oil', 'salt', 'pastry', 'flesh', 'bitter', 'sugar', 'leather', 'herbal', 'creamy', 'table', 'brown', 'golden', 'gold', 'extract', 'broad', 'natural', 'salmon', 'tongue', 'dry', 'pure', 'root', 'sea', 'port', 'chewy', 'solid', 'blue', 'pink', 'ground', 'beef', 'purple', 'spring', 'lean', 'raw', 'red', 'black', 'white', 'yellow', 'mature', 'tropical', 'meat', 'wild', 'new', 'juice', 'firm', 'sweet', 'fresh', 'light', 'flower', 'green', 'soft', 'skin', 'spice', 'dark', 'herb', 'palate', 'valley', 'finish', 'drink', 'flavor', 'fruit', 'aroma', 'note', 'texture', 'thi', 'acidity']
tfidf_vectorizer = TfidfVectorizer(stop_words=stops)
tfidf_matrix = tfidf_vectorizer.fit_transform(noun_list)

# %%
# features holds a list of all the words in the tfidf's vocabulary in the same order as the column in the matrix
features = tfidf_vectorizer.get_feature_names()
weights = np.asarray(tfidf_matrix.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term':features, 'weights':weights})
weights_df = weights_df.sort_values(by='weights', ascending=False)

# %%
# call the foods database 
food_db = pd.read_csv('data/raw/8b. AUSNUT 2011-13 AHS Food Nutrient Database.csv')

# %%
# process foods
test = set(word.strip().lower() for ls in list(map(lambda x:x.split(',') ,food_db['Food Name'].tolist())) for word in ls)

# %%
# pickout the foods from the wine list
terms = weights_df[weights_df['weights'] > 0.001]
foods = []
for term in terms['term']:
    if term in test:
        foods.append(term)

# %%
print(foods)
# Out:
# ['cherry', 'berry', 'plum', 'apple', 'blackberry', 'vanilla', 'pepper', 'citrus', 'lemon', 'raspberry', 'peach', 'pear', 'chocolate', 'currant', 'licorice', 'lime', 'coffee', 'melon', 'grapefruit', 'honey', 'apricot', 'pineapple', 'strawberry', 'cinnamon', 'almond', 'mocha', 'mint', 'orange', 'jam', 'grape', 'blueberry', 'tea', 'sage', 'pie', 'caramel', 'cranberry', 'raisin', 'olive', 'tomato', 'coconut', 'butter', 'bacon', 'fig', 'mango', 'banana', 'thyme', 'prune', 'mushroom', 'pomegranate', 'butterscotch', 'ginger', 'lychee', 'mousse', 'bread', 'nut', 'truffle', 'yeast', 'jasmine', 'nectarine', 'hazelnut', 'fennel', 'liqueur', 'tart', 'herbs', 'quince', 'dill', 'watermelon', 'heart', 'lamb', 'pork', 'chicken', 'guava', 'seafood', 'maple', 'custard', 'energy', 'soy', 'beer', 'cooking', 'coating']

# %% [markdown]
# # Co-occurence matrix

# %%
wine_flavors = ['cherry', 'berry', 'plum', 'apple', 'blackberry', 'vanilla', 'pepper', 'citrus', 'lemon', 'raspberry', 'peach', 'pear', 'chocolate', 'currant', 'licorice', 'lime', 'coffee', 'melon', 'grapefruit', 'honey', 'apricot', 'pineapple', 'strawberry', 'cinnamon', 'almond', 'mocha', 'mint', 'orange', 'jam', 'grape', 'blueberry', 'tea', 'sage', 'pie', 'caramel', 'cranberry', 'raisin', 'olive', 'tomato', 'coconut', 'butter', 'bacon', 'fig', 'mango', 'banana', 'thyme', 'prune', 'mushroom', 'pomegranate', 'butterscotch', 'ginger', 'lychee', 'mousse', 'bread', 'nut', 'truffle', 'yeast', 'jasmine', 'nectarine', 'hazelnut', 'fennel', 'liqueur', 'tart', 'herbs', 'quince', 'dill', 'watermelon', 'heart', 'lamb', 'pork', 'chicken', 'guava', 'seafood', 'maple', 'custard', 'energy', 'soy', 'beer', 'cooking', 'coating']

# %%
wine_test = pd.read_csv('data/modified/wines_with_nouns.csv')

# %%
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
def noun_preprocess(review):
    tokenized_review = tokenize(review)
    tokens = [token for token in tokenized_review if token in test]
    return tokens

# %%
import collections
from nltk.corpus import stopwords
import string
 
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via']

# %%
from collections import defaultdict
# remember to include the other import from the previous post
 
com = defaultdict(lambda : defaultdict(int))

for review in wine_test['noun_words']:
    terms_only = [term for term in preprocess(str(review)) if term not in stop]
    
    # Build co-occurrence matrix
    for i in range(len(terms_only)-1):            
        for j in range(i+1, len(terms_only)):
            w1, w2 = sorted([terms_only[i], terms_only[j]])                
            if w1 != w2:
                com[w1][w2] += 1

# %%
import operator
com_max = []
# For each term, look for the most common co-occurrent terms
for t1 in com:
    t1_max_terms = sorted(com[t1].items(), key=operator.itemgetter(1), reverse=True)[:5]
    for t2, t2_count in t1_max_terms:
        com_max.append(((t1, t2), t2_count))
# Get the most frequent co-occurrences
terms_max = sorted(com_max, key=operator.itemgetter(1), reverse=True)
print(terms_max[:100])
# Out:
# [(('fruit', 'wine'), 31321), (('acidity', 'wine'), 25873), (('fruit', 'palate'), 13636), (('cherry', 'wine'), 13475), (('finish', 'palate'), 12968), (('finish', 'fruit'), 12773), (('finish', 'wine'), 12636), (('palate', 'wine'), 12347), (('acidity', 'fruit'), 11951), (('nose', 'palate'), 11692), (('cherry', 'palate'), 11460), (('texture', 'wine'), 11027), (('spice', 'wine'), 10787), (('cherry', 'fruit'), 9600), (('acidity', 'palate'), 9064), (('character', 'wine'), 8692), (('oak', 'wine'), 8604), (('fruity', 'wine'), 8448), (('fruit', 'spice'), 8173), (('berry', 'wine'), 7800), (('cherry', 'finish'), 7694), (('fruit', 'oak'), 7391), (('wine', 'wood'), 7301), (('structure', 'wine'), 7239), (('berry', 'palate'), 7051), (('palate', 'spice'), 6917), (('acidity', 'finish'), 6875), (('cherry', 'spice'), 6663), (('palate', 'plum'), 6565), (('apple', 'wine'), 6531), (('plum', 'wine'), 6435), (('blend', 'wine'), 6306), (('fruit', 'nose'), 6271), (('berry', 'finish'), 5994), (('acidity', 'cherry'), 5946), (('nose', 'wine'), 5939), (('apple', 'palate'), 5782), (('blackberry', 'wine'), 5778), (('finish', 'plum'), 5660), (('finish', 'nose'), 5651), (('citrus', 'wine'), 5195), (('berry', 'cherry'), 5169), (('oak', 'palate'), 5098), (('touch', 'wine'), 4993), (('blend', 'fruit'), 4931), (('vanilla', 'wine'), 4923), (('berry', 'fruit'), 4862), (('palate', 'pepper'), 4699), (('currant', 'wine'), 4647), (('lemon', 'wine'), 4584), (('mineral', 'wine'), 4542), (('pepper', 'wine'), 4489), (('chocolate', 'wine'), 4434), (('lemon', 'palate'), 4396), (('apple', 'finish'), 4310), (('pear', 'wine'), 3993), (('apple', 'fruit'), 3881), (('richness', 'wine'), 3873), (('vineyard', 'wine'), 3854), (('blackberry', 'palate'), 3838), (('palate', 'vanilla'), 3837), (('note', 'palate'), 3761), (('mouth', 'wine'), 3735), (('peach', 'wine'), 3711), (('blackberry', 'fruit'), 3700), (('flavor', 'wine'), 3628), (('citrus', 'fruit'), 3617), (('blackberry', 'cherry'), 3617), (('style', 'wine'), 3605), (('blackberry', 'finish'), 3574), (('citrus', 'palate'), 3561), (('raspberry', 'wine'), 3543), (('blend', 'palate'), 3542), (('apple', 'pear'), 3519), (('balance', 'wine'), 3506), (('oak', 'vanilla'), 3415), (('character', 'fruit'), 3327), (('time', 'wine'), 3274), (('aging', 'wine'), 3264), (('blend', 'cherry'), 3241), (('vintage', 'wine'), 3182), (('herb', 'palate'), 3176), (('toast', 'wine'), 3171), (('hint', 'palate'), 3163), (('plum', 'spice'), 3139), (('fruitiness', 'wine'), 3123), (('blend', 'finish'), 3113), (('edge', 'wine'), 3064), (('color', 'wine'), 3038), (('chocolate', 'fruit'), 2963), (('aftertaste', 'wine'), 2940), (('citrus', 'finish'), 2938), (('licorice', 'palate'), 2908), (('freshness', 'wine'), 2858), (('weight', 'wine'), 2845), (('oak', 'spice'), 2788), (('nose', 'plum'), 2772), (('nose', 'spice'), 2771), (('core', 'wine'), 2733), (('chocolate', 'finish'), 2649)]

# %%
search_word = 'vanilla'
count_search = collections.Counter()
for review in wine['description']:
    terms_only = [term for term in preprocess(review) 
                  if term not in stop]
    if search_word in terms_only:
        count_search.update(terms_only)
print("Co-occurrence for %s:" % search_word)
print(count_search.most_common(100))
# Out:
# Co-occurrence for vanilla:
# [('vanilla', 10454), ('flavors', 5658), ('wine', 4473), ('The', 4310), ('aromas', 3603), ('palate', 3576), ('fruit', 3287), ('finish', 3225), ('This', 2972), ('oak', 2862), ('cherry', 2829), ('tannins', 2213), ('black', 2131), ('acidity', 2076), ('spice', 2005), ('notes', 1901), ('ripe', 1737), ('A', 1659), ("It's", 1583), ('plum', 1508), ('nose', 1507), ('Drink', 1476), ('sweet', 1435), ('rich', 1333), ('It', 1238), ('red', 1225), ('berry', 1189), ('offers', 1175), ('toast', 1115), ('blend', 1107), ('blackberry', 1097), ('raspberry', 931), ('Cabernet', 929), ('soft', 904), ('apple', 897), ('chocolate', 878), ('shows', 872), ('Chardonnay', 868), ('creamy', 831), ('texture', 797), ('white', 774), ('crisp', 760), ('dark', 735), ('fresh', 711), ('Sauvignon', 705), ('good', 690), ('dry', 683), ('touch', 679), ('dried', 655), ('coffee', 652), ('full', 649), ('pepper', 644), ('lead', 641), ('lemon', 628), ('fruits', 618), ('peach', 615), ('alongside', 607), ('well', 602), ('Aromas', 598), ('pear', 591), ('oaky', 580), ('citrus', 576), ('wood', 567), ('tobacco', 560), ('note', 554), ('along', 548), ('opens', 547), ('–', 540), ('toasted', 532), ('like', 532), ('balanced', 531), ('pineapple', 528), ('bright', 520), ('cinnamon', 518), ('green', 517), ('mouth', 515), ('Merlot', 513), ('licorice', 509), ('Pinot', 504), ('smooth', 496), ('orange', 492), ('drink', 491), ('long', 488), ('light', 484), ('firm', 484), ('full-bodied', 483), ('mocha', 480), ('buttered', 475), ('cassis', 473), ('barrel', 468), ('balance', 460), ('bit', 459), ('hint', 459), ('tart', 454), ('juicy', 454), ('bean', 452), ('cream', 446), ('years', 438), ('honey', 435), ('Syrah', 431)]

# %%
stop_list = ['wine', 'fruit', 'light', 'bean', 'red', 'firm', 'extract', 
             'skin', 'sauce', 'white', 'drink', 'gold', 'tongue', 'spring']
flavor_cooccurences = {}
for flavor in wine_flavors:
    count_search = collections.Counter()
    for review in wine_test['noun_words']:
        terms_only = [term for term in noun_preprocess(str(review)) if term not in stop_list]
        if flavor in terms_only:
            terms_only.remove(flavor)
            count_search.update(terms_only)
#     print("Co-occurrence for %s:" % search_word)
#     print(count_search.most_common(20))
    flavor_cooccurences[flavor] = [item[0] for item in count_search.most_common(20)]

# %%
flavor_cooccurences
# Out:
# {'almond': ['apple',
#   'peach',
#   'citrus',
#   'pear',
#   'cherry',
#   'flower',
#   'lemon',
#   'spice',
#   'honey',
#   'apricot',
#   'berry',
#   'vanilla',
#   'melon',
#   'paste',
#   'nut',
#   'grapefruit',
#   'lime',
#   'raspberry',
#   'butter',
#   'pineapple'],
#  'apple': ['pear',
#   'lemon',
#   'citrus',
#   'peach',
#   'lime',
#   'apple',
#   'melon',
#   'spice',
#   'vanilla',
#   'grapefruit',
#   'almond',
#   'honey',
#   'flower',
#   'pineapple',
#   'apricot',
#   'orange',
#   'mousse',
#   'juice',
#   'butter',
#   'bread'],
#  'apricot': ['peach',
#   'honey',
#   'lemon',
#   'citrus',
#   'pear',
#   'apple',
#   'vanilla',
#   'spice',
#   'pineapple',
#   'orange',
#   'almond',
#   'lime',
#   'melon',
#   'grapefruit',
#   'flower',
#   'jam',
#   'mango',
#   'sugar',
#   'butterscotch',
#   'grape'],
#  'bacon': ['cherry',
#   'blackberry',
#   'pepper',
#   'spice',
#   'berry',
#   'plum',
#   'chocolate',
#   'licorice',
#   'fat',
#   'currant',
#   'meat',
#   'raspberry',
#   'vanilla',
#   'jam',
#   'blueberry',
#   'leather',
#   'mocha',
#   'beef',
#   'coffee',
#   'cinnamon'],
#  'banana': ['apple',
#   'peach',
#   'melon',
#   'citrus',
#   'pear',
#   'vanilla',
#   'pineapple',
#   'lemon',
#   'mango',
#   'cherry',
#   'lime',
#   'spice',
#   'cream',
#   'apricot',
#   'banana',
#   'honey',
#   'almond',
#   'grapefruit',
#   'flower',
#   'orange'],
#  'beer': ['root',
#   'cherry',
#   'spice',
#   'licorice',
#   'berry',
#   'chocolate',
#   'blackberry',
#   'plum',
#   'vanilla',
#   'pepper',
#   'raspberry',
#   'leather',
#   'coffee',
#   'mint',
#   'blueberry',
#   'apple',
#   'cinnamon',
#   'tea',
#   'almond',
#   'currant'],
#  'berry': ['cherry',
#   'spice',
#   'plum',
#   'pepper',
#   'raspberry',
#   'berry',
#   'leather',
#   'licorice',
#   'chocolate',
#   'vanilla',
#   'blackberry',
#   'coffee',
#   'currant',
#   'mint',
#   'cinnamon',
#   'flower',
#   'mocha',
#   'tomato',
#   'olive',
#   'sage'],
#  'blackberry': ['cherry',
#   'spice',
#   'plum',
#   'chocolate',
#   'pepper',
#   'licorice',
#   'currant',
#   'berry',
#   'vanilla',
#   'jam',
#   'leather',
#   'coffee',
#   'blueberry',
#   'mocha',
#   'raspberry',
#   'blackberry',
#   'meat',
#   'cinnamon',
#   'mint',
#   'raisin'],
#  'blueberry': ['cherry',
#   'blackberry',
#   'spice',
#   'plum',
#   'chocolate',
#   'pepper',
#   'vanilla',
#   'berry',
#   'licorice',
#   'coffee',
#   'leather',
#   'raspberry',
#   'currant',
#   'meat',
#   'beef',
#   'mocha',
#   'jam',
#   'cinnamon',
#   'mint',
#   'blueberry'],
#  'bread': ['apple',
#   'citrus',
#   'lemon',
#   'almond',
#   'pear',
#   'vanilla',
#   'peach',
#   'cherry',
#   'lime',
#   'honey',
#   'walnut',
#   'spice',
#   'flower',
#   'berry',
#   'mousse',
#   'hazelnut',
#   'pastry',
#   'apricot',
#   'cream',
#   'raspberry'],
#  'butter': ['apple',
#   'vanilla',
#   'lemon',
#   'pear',
#   'peach',
#   'spice',
#   'pineapple',
#   'almond',
#   'lime',
#   'citrus',
#   'cream',
#   'honey',
#   'salt',
#   'cherry',
#   'sea',
#   'caramel',
#   'melon',
#   'apricot',
#   'butterscotch',
#   'berry'],
#  'butterscotch': ['vanilla',
#   'apple',
#   'pineapple',
#   'peach',
#   'lemon',
#   'apricot',
#   'caramel',
#   'honey',
#   'pear',
#   'spice',
#   'cherry',
#   'citrus',
#   'almond',
#   'orange',
#   'butter',
#   'melon',
#   'cream',
#   'jam',
#   'lime',
#   'cinnamon'],
#  'caramel': ['vanilla',
#   'cherry',
#   'apple',
#   'spice',
#   'chocolate',
#   'honey',
#   'blackberry',
#   'plum',
#   'lemon',
#   'berry',
#   'peach',
#   'pear',
#   'apricot',
#   'pineapple',
#   'butterscotch',
#   'raspberry',
#   'coffee',
#   'citrus',
#   'butter',
#   'currant'],
#  'cherry': ['spice',
#   'berry',
#   'plum',
#   'raspberry',
#   'pepper',
#   'blackberry',
#   'vanilla',
#   'licorice',
#   'chocolate',
#   'leather',
#   'cherry',
#   'cinnamon',
#   'currant',
#   'coffee',
#   'mocha',
#   'mint',
#   'flower',
#   'strawberry',
#   'pie',
#   'sage'],
#  'chicken': ['cherry',
#   'roast',
#   'lemon',
#   'citrus',
#   'spice',
#   'pork',
#   'apple',
#   'salad',
#   'peach',
#   'vanilla',
#   'fish',
#   'berry',
#   'pasta',
#   'almond',
#   'pear',
#   'apricot',
#   'honey',
#   'pineapple',
#   'pepper',
#   'beef'],
#  'chocolate': ['cherry',
#   'blackberry',
#   'spice',
#   'plum',
#   'berry',
#   'vanilla',
#   'coffee',
#   'milk',
#   'pepper',
#   'licorice',
#   'currant',
#   'raspberry',
#   'leather',
#   'jam',
#   'blueberry',
#   'mocha',
#   'mint',
#   'cinnamon',
#   'raisin',
#   'chocolate'],
#  'cinnamon': ['cherry',
#   'spice',
#   'berry',
#   'pepper',
#   'raspberry',
#   'vanilla',
#   'plum',
#   'blackberry',
#   'leather',
#   'chocolate',
#   'licorice',
#   'flower',
#   'strawberry',
#   'apple',
#   'mocha',
#   'mint',
#   'sugar',
#   'jam',
#   'currant',
#   'pie'],
#  'citrus': ['apple',
#   'peach',
#   'pear',
#   'lemon',
#   'melon',
#   'lime',
#   'grapefruit',
#   'spice',
#   'flower',
#   'pineapple',
#   'vanilla',
#   'honey',
#   'almond',
#   'apricot',
#   'citrus',
#   'pepper',
#   'cherry',
#   'orange',
#   'plum',
#   'grape'],
#  'coating': ['cherry',
#   'chocolate',
#   'blackberry',
#   'plum',
#   'vanilla',
#   'spice',
#   'pepper',
#   'raspberry',
#   'currant',
#   'berry',
#   'licorice',
#   'coffee',
#   'pineapple',
#   'steak',
#   'mocha',
#   'milk',
#   'jam',
#   'orange',
#   'pomegranate',
#   'sage'],
#  'coconut': ['vanilla',
#   'cherry',
#   'berry',
#   'spice',
#   'plum',
#   'blackberry',
#   'coffee',
#   'chocolate',
#   'licorice',
#   'mocha',
#   'raspberry',
#   'pepper',
#   'sage',
#   'apple',
#   'lemon',
#   'leather',
#   'raisin',
#   'pear',
#   'currant',
#   'prune'],
#  'coffee': ['cherry',
#   'plum',
#   'chocolate',
#   'berry',
#   'spice',
#   'vanilla',
#   'blackberry',
#   'licorice',
#   'pepper',
#   'mocha',
#   'leather',
#   'raspberry',
#   'currant',
#   'sage',
#   'coconut',
#   'blueberry',
#   'olive',
#   'meat',
#   'coffee',
#   'mint'],
#  'cooking': ['spice',
#   'cherry',
#   'berry',
#   'pepper',
#   'licorice',
#   'plum',
#   'blackberry',
#   'raspberry',
#   'leather',
#   'ground',
#   'coffee',
#   'jam',
#   'currant',
#   'vanilla',
#   'flower',
#   'cinnamon',
#   'sage',
#   'mocha',
#   'mint',
#   'raisin'],
#  'cranberry': ['cherry',
#   'raspberry',
#   'spice',
#   'plum',
#   'pepper',
#   'vanilla',
#   'blackberry',
#   'berry',
#   'pomegranate',
#   'strawberry',
#   'tea',
#   'leather',
#   'cinnamon',
#   'chocolate',
#   'sage',
#   'thyme',
#   'currant',
#   'licorice',
#   'coffee',
#   'fennel'],
#  'currant': ['cherry',
#   'blackberry',
#   'plum',
#   'spice',
#   'berry',
#   'pepper',
#   'chocolate',
#   'licorice',
#   'raspberry',
#   'vanilla',
#   'mocha',
#   'leather',
#   'coffee',
#   'jam',
#   'meat',
#   'blueberry',
#   'beef',
#   'mint',
#   'cinnamon',
#   'pie'],
#  'custard': ['lemon',
#   'vanilla',
#   'apple',
#   'peach',
#   'pineapple',
#   'pear',
#   'lime',
#   'spice',
#   'citrus',
#   'butter',
#   'apricot',
#   'honey',
#   'butterscotch',
#   'melon',
#   'orange',
#   'cream',
#   'banana',
#   'pie',
#   'cherry',
#   'cinnamon'],
#  'dill': ['cherry',
#   'vanilla',
#   'spice',
#   'blackberry',
#   'pepper',
#   'plum',
#   'berry',
#   'licorice',
#   'raspberry',
#   'thyme',
#   'chocolate',
#   'lemon',
#   'leather',
#   'apple',
#   'mint',
#   'blueberry',
#   'lime',
#   'currant',
#   'coffee',
#   'fennel'],
#  'energy': ['plum',
#   'cherry',
#   'apple',
#   'lemon',
#   'berry',
#   'spice',
#   'lime',
#   'pepper',
#   'pear',
#   'raspberry',
#   'peach',
#   'citrus',
#   'grapefruit',
#   'blackberry',
#   'vanilla',
#   'chocolate',
#   'juice',
#   'thyme',
#   'strawberry',
#   'leather'],
#  'fennel': ['cherry',
#   'pepper',
#   'plum',
#   'spice',
#   'raspberry',
#   'blackberry',
#   'berry',
#   'thyme',
#   'apple',
#   'licorice',
#   'vanilla',
#   'peach',
#   'pomegranate',
#   'sage',
#   'lemon',
#   'chocolate',
#   'strawberry',
#   'cinnamon',
#   'cranberry',
#   'pear'],
#  'fig': ['cherry',
#   'plum',
#   'spice',
#   'blackberry',
#   'vanilla',
#   'chocolate',
#   'berry',
#   'melon',
#   'raisin',
#   'licorice',
#   'pepper',
#   'citrus',
#   'pear',
#   'lemon',
#   'coffee',
#   'honey',
#   'apple',
#   'leather',
#   'apricot',
#   'mocha'],
#  'ginger': ['spice',
#   'apple',
#   'peach',
#   'pear',
#   'cherry',
#   'lemon',
#   'citrus',
#   'berry',
#   'apricot',
#   'flower',
#   'vanilla',
#   'honey',
#   'almond',
#   'cinnamon',
#   'licorice',
#   'plum',
#   'pepper',
#   'lime',
#   'melon',
#   'pineapple'],
#  'grape': ['cherry',
#   'spice',
#   'apple',
#   'berry',
#   'plum',
#   'blackberry',
#   'citrus',
#   'pepper',
#   'peach',
#   'lemon',
#   'pear',
#   'vanilla',
#   'chocolate',
#   'lime',
#   'raspberry',
#   'melon',
#   'licorice',
#   'apricot',
#   'juice',
#   'almond'],
#  'grapefruit': ['lemon',
#   'lime',
#   'citrus',
#   'apple',
#   'peach',
#   'pear',
#   'melon',
#   'pineapple',
#   'orange',
#   'spice',
#   'honey',
#   'apricot',
#   'pepper',
#   'grapefruit',
#   'almond',
#   'juice',
#   'vanilla',
#   'tomato',
#   'flower',
#   'grape'],
#  'guava': ['pineapple',
#   'apple',
#   'lime',
#   'lemon',
#   'peach',
#   'mango',
#   'pear',
#   'melon',
#   'citrus',
#   'vanilla',
#   'grapefruit',
#   'banana',
#   'apricot',
#   'guava',
#   'honey',
#   'grape',
#   'orange',
#   'spice',
#   'juice',
#   'flesh'],
#  'hazelnut': ['apple',
#   'lemon',
#   'pear',
#   'citrus',
#   'peach',
#   'spice',
#   'flower',
#   'cherry',
#   'vanilla',
#   'almond',
#   'berry',
#   'honey',
#   'apricot',
#   'bread',
#   'lime',
#   'coffee',
#   'chocolate',
#   'nut',
#   'licorice',
#   'sage'],
#  'heart': ['cherry',
#   'spice',
#   'plum',
#   'blackberry',
#   'lemon',
#   'citrus',
#   'berry',
#   'chocolate',
#   'vanilla',
#   'pepper',
#   'currant',
#   'apple',
#   'leather',
#   'raspberry',
#   'lime',
#   'mocha',
#   'peach',
#   'tea',
#   'cinnamon',
#   'pear'],
#  'herbs': ['plum',
#   'berry',
#   'cherry',
#   'tomato',
#   'spice',
#   'blackberry',
#   'raspberry',
#   'chocolate',
#   'vanilla',
#   'apple',
#   'pepper',
#   'licorice',
#   'olive',
#   'mint',
#   'citrus',
#   'leather',
#   'lemon',
#   'lime',
#   'coffee',
#   'currant'],
#  'honey': ['peach',
#   'lemon',
#   'apple',
#   'apricot',
#   'citrus',
#   'vanilla',
#   'pear',
#   'spice',
#   'lime',
#   'almond',
#   'pineapple',
#   'orange',
#   'melon',
#   'flower',
#   'sugar',
#   'grapefruit',
#   'caramel',
#   'honey',
#   'mango',
#   'cream'],
#  'jam': ['blackberry',
#   'cherry',
#   'raspberry',
#   'chocolate',
#   'spice',
#   'vanilla',
#   'pepper',
#   'plum',
#   'licorice',
#   'pineapple',
#   'berry',
#   'currant',
#   'mocha',
#   'apricot',
#   'cinnamon',
#   'leather',
#   'blueberry',
#   'strawberry',
#   'orange',
#   'coffee'],
#  'jasmine': ['peach',
#   'apple',
#   'pear',
#   'lemon',
#   'lime',
#   'citrus',
#   'honey',
#   'apricot',
#   'orange',
#   'almond',
#   'melon',
#   'tea',
#   'flower',
#   'pineapple',
#   'grapefruit',
#   'grape',
#   'sugar',
#   'salt',
#   'vanilla',
#   'spice'],
#  'lamb': ['cherry',
#   'beef',
#   'spice',
#   'pepper',
#   'steak',
#   'blackberry',
#   'vanilla',
#   'pork',
#   'meat',
#   'berry',
#   'chocolate',
#   'plum',
#   'raspberry',
#   'cinnamon',
#   'roast',
#   'leather',
#   'currant',
#   'blueberry',
#   'tuna',
#   'salmon'],
#  'lemon': ['apple',
#   'lime',
#   'peach',
#   'pear',
#   'citrus',
#   'grapefruit',
#   'lemon',
#   'vanilla',
#   'honey',
#   'pineapple',
#   'spice',
#   'apricot',
#   'orange',
#   'melon',
#   'almond',
#   'flower',
#   'juice',
#   'butter',
#   'pepper',
#   'plum'],
#  'licorice': ['cherry',
#   'spice',
#   'berry',
#   'blackberry',
#   'plum',
#   'pepper',
#   'leather',
#   'raspberry',
#   'chocolate',
#   'vanilla',
#   'coffee',
#   'currant',
#   'mocha',
#   'mint',
#   'cinnamon',
#   'sage',
#   'flower',
#   'jam',
#   'raisin',
#   'blueberry'],
#  'lime': ['lemon',
#   'apple',
#   'peach',
#   'grapefruit',
#   'pear',
#   'citrus',
#   'melon',
#   'pineapple',
#   'lime',
#   'vanilla',
#   'honey',
#   'juice',
#   'orange',
#   'apricot',
#   'spice',
#   'pepper',
#   'mango',
#   'flower',
#   'lychee',
#   'sugar'],
#  'liqueur': ['cherry',
#   'chocolate',
#   'blackberry',
#   'spice',
#   'jam',
#   'coffee',
#   'raspberry',
#   'licorice',
#   'vanilla',
#   'pepper',
#   'berry',
#   'plum',
#   'currant',
#   'apple',
#   'pie',
#   'leather',
#   'mocha',
#   'milk',
#   'blueberry',
#   'cinnamon'],
#  'lychee': ['spice',
#   'melon',
#   'lime',
#   'peach',
#   'citrus',
#   'apple',
#   'lemon',
#   'pear',
#   'lychee',
#   'grapefruit',
#   'honey',
#   'mango',
#   'pineapple',
#   'apricot',
#   'pepper',
#   'sugar',
#   'orange',
#   'vanilla',
#   'grape',
#   'banana'],
#  'mango': ['pineapple',
#   'peach',
#   'lime',
#   'melon',
#   'apple',
#   'lemon',
#   'pear',
#   'honey',
#   'apricot',
#   'citrus',
#   'orange',
#   'vanilla',
#   'guava',
#   'spice',
#   'banana',
#   'grapefruit',
#   'lychee',
#   'sugar',
#   'juice',
#   'butterscotch'],
#  'maple': ['syrup',
#   'vanilla',
#   'blackberry',
#   'berry',
#   'sugar',
#   'spice',
#   'cherry',
#   'honey',
#   'plum',
#   'chocolate',
#   'coffee',
#   'apricot',
#   'mocha',
#   'bacon',
#   'jam',
#   'caramel',
#   'almond',
#   'cinnamon',
#   'raspberry',
#   'raisin'],
#  'melon': ['apple',
#   'peach',
#   'citrus',
#   'pear',
#   'lime',
#   'lemon',
#   'grapefruit',
#   'spice',
#   'vanilla',
#   'pineapple',
#   'honey',
#   'apricot',
#   'almond',
#   'banana',
#   'orange',
#   'mango',
#   'melon',
#   'lychee',
#   'grape',
#   'sugar'],
#  'mint': ['cherry',
#   'berry',
#   'spice',
#   'plum',
#   'blackberry',
#   'pepper',
#   'raspberry',
#   'chocolate',
#   'licorice',
#   'leather',
#   'vanilla',
#   'cinnamon',
#   'coffee',
#   'currant',
#   'sage',
#   'thyme',
#   'flower',
#   'blueberry',
#   'mocha',
#   'strawberry'],
#  'mocha': ['cherry',
#   'blackberry',
#   'plum',
#   'spice',
#   'berry',
#   'vanilla',
#   'licorice',
#   'pepper',
#   'coffee',
#   'chocolate',
#   'raspberry',
#   'currant',
#   'leather',
#   'cinnamon',
#   'jam',
#   'blueberry',
#   'coconut',
#   'mint',
#   'meat',
#   'flower'],
#  'mousse': ['apple',
#   'lemon',
#   'peach',
#   'citrus',
#   'pear',
#   'lime',
#   'flower',
#   'vanilla',
#   'honey',
#   'strawberry',
#   'bread',
#   'berry',
#   'almond',
#   'spice',
#   'cherry',
#   'apricot',
#   'cream',
#   'grapefruit',
#   'pastry',
#   'currant'],
#  'mushroom': ['cherry',
#   'spice',
#   'berry',
#   'plum',
#   'raspberry',
#   'pepper',
#   'leather',
#   'blackberry',
#   'chocolate',
#   'vanilla',
#   'licorice',
#   'risotto',
#   'meat',
#   'cinnamon',
#   'coffee',
#   'tea',
#   'button',
#   'strawberry',
#   'apple',
#   'citrus'],
#  'nectarine': ['apple',
#   'peach',
#   'pear',
#   'lemon',
#   'citrus',
#   'lime',
#   'melon',
#   'grapefruit',
#   'apricot',
#   'flower',
#   'pineapple',
#   'vanilla',
#   'almond',
#   'orange',
#   'honey',
#   'salt',
#   'juice',
#   'sea',
#   'grape',
#   'jasmine'],
#  'nut': ['apple',
#   'cherry',
#   'spice',
#   'almond',
#   'honey',
#   'lemon',
#   'citrus',
#   'pear',
#   'flower',
#   'peach',
#   'apricot',
#   'berry',
#   'vanilla',
#   'lime',
#   'butter',
#   'plum',
#   'grapefruit',
#   'macadamia',
#   'pepper',
#   'blackberry'],
#  'olive': ['berry',
#   'plum',
#   'cherry',
#   'blackberry',
#   'spice',
#   'pepper',
#   'chocolate',
#   'meat',
#   'coffee',
#   'vanilla',
#   'raspberry',
#   'leather',
#   'olive',
#   'licorice',
#   'currant',
#   'mocha',
#   'tomato',
#   'mint',
#   'blueberry',
#   'tea'],
#  'orange': ['lemon',
#   'apple',
#   'peach',
#   'vanilla',
#   'lime',
#   'apricot',
#   'honey',
#   'citrus',
#   'pineapple',
#   'cherry',
#   'spice',
#   'pear',
#   'grapefruit',
#   'melon',
#   'mandarin',
#   'mango',
#   'tea',
#   'pepper',
#   'sugar',
#   'jam'],
#  'peach': ['apple',
#   'citrus',
#   'lemon',
#   'pear',
#   'apricot',
#   'melon',
#   'lime',
#   'honey',
#   'pineapple',
#   'vanilla',
#   'flower',
#   'almond',
#   'grapefruit',
#   'spice',
#   'orange',
#   'peach',
#   'mango',
#   'jasmine',
#   'banana',
#   'grape'],
#  'pear': ['apple',
#   'lemon',
#   'peach',
#   'citrus',
#   'lime',
#   'melon',
#   'spice',
#   'vanilla',
#   'pineapple',
#   'apricot',
#   'almond',
#   'pear',
#   'honey',
#   'flower',
#   'grapefruit',
#   'pepper',
#   'orange',
#   'juice',
#   'butter',
#   'grape'],
#  'pepper': ['cherry',
#   'spice',
#   'berry',
#   'blackberry',
#   'plum',
#   'raspberry',
#   'licorice',
#   'leather',
#   'chocolate',
#   'vanilla',
#   'currant',
#   'cinnamon',
#   'ground',
#   'coffee',
#   'meat',
#   'pepper',
#   'flower',
#   'mocha',
#   'blueberry',
#   'mint'],
#  'pie': ['cherry',
#   'vanilla',
#   'blackberry',
#   'spice',
#   'plum',
#   'apple',
#   'raspberry',
#   'chocolate',
#   'pepper',
#   'berry',
#   'cinnamon',
#   'lemon',
#   'lime',
#   'licorice',
#   'currant',
#   'blueberry',
#   'pineapple',
#   'mocha',
#   'cream',
#   'jam'],
#  'pineapple': ['peach',
#   'lemon',
#   'apple',
#   'vanilla',
#   'citrus',
#   'pear',
#   'lime',
#   'apricot',
#   'honey',
#   'mango',
#   'orange',
#   'melon',
#   'spice',
#   'grapefruit',
#   'jam',
#   'guava',
#   'butterscotch',
#   'sugar',
#   'banana',
#   'cream'],
#  'plum': ['cherry',
#   'berry',
#   'spice',
#   'blackberry',
#   'vanilla',
#   'pepper',
#   'raspberry',
#   'chocolate',
#   'licorice',
#   'plum',
#   'leather',
#   'currant',
#   'coffee',
#   'mocha',
#   'cinnamon',
#   'tomato',
#   'blueberry',
#   'mint',
#   'olive',
#   'meat'],
#  'pomegranate': ['cherry',
#   'raspberry',
#   'spice',
#   'pepper',
#   'plum',
#   'berry',
#   'cranberry',
#   'tea',
#   'juice',
#   'strawberry',
#   'vanilla',
#   'cinnamon',
#   'sage',
#   'thyme',
#   'chocolate',
#   'leather',
#   'blackberry',
#   'fennel',
#   'coffee',
#   'licorice'],
#  'pork': ['cherry',
#   'spice',
#   'pepper',
#   'roast',
#   'beef',
#   'blackberry',
#   'chicken',
#   'lamb',
#   'plum',
#   'vanilla',
#   'berry',
#   'meat',
#   'chocolate',
#   'leather',
#   'blueberry',
#   'fat',
#   'licorice',
#   'currant',
#   'bacon',
#   'raspberry'],
#  'prune': ['raisin',
#   'blackberry',
#   'cherry',
#   'plum',
#   'spice',
#   'berry',
#   'chocolate',
#   'vanilla',
#   'leather',
#   'licorice',
#   'coffee',
#   'pepper',
#   'mocha',
#   'fig',
#   'coconut',
#   'mint',
#   'currant',
#   'raspberry',
#   'jam',
#   'meat'],
#  'quince': ['apple',
#   'lemon',
#   'pear',
#   'lime',
#   'peach',
#   'spice',
#   'citrus',
#   'apricot',
#   'honey',
#   'grapefruit',
#   'pineapple',
#   'orange',
#   'almond',
#   'vanilla',
#   'melon',
#   'mango',
#   'plum',
#   'lychee',
#   'caramel',
#   'quince'],
#  'raisin': ['plum',
#   'blackberry',
#   'berry',
#   'cherry',
#   'prune',
#   'spice',
#   'chocolate',
#   'licorice',
#   'vanilla',
#   'pepper',
#   'leather',
#   'coffee',
#   'fig',
#   'mocha',
#   'currant',
#   'jam',
#   'raspberry',
#   'raisin',
#   'coconut',
#   'blueberry'],
#  'raspberry': ['cherry',
#   'spice',
#   'plum',
#   'berry',
#   'pepper',
#   'vanilla',
#   'licorice',
#   'leather',
#   'cinnamon',
#   'blackberry',
#   'chocolate',
#   'jam',
#   'currant',
#   'strawberry',
#   'flower',
#   'mint',
#   'mocha',
#   'cranberry',
#   'coffee',
#   'tea'],
#  'sage': ['cherry',
#   'berry',
#   'spice',
#   'pepper',
#   'plum',
#   'licorice',
#   'leather',
#   'raspberry',
#   'blackberry',
#   'coffee',
#   'thyme',
#   'vanilla',
#   'flower',
#   'mint',
#   'chocolate',
#   'peach',
#   'currant',
#   'apple',
#   'citrus',
#   'lemon'],
#  'seafood': ['citrus',
#   'lemon',
#   'apple',
#   'peach',
#   'pear',
#   'spice',
#   'lime',
#   'grapefruit',
#   'melon',
#   'salad',
#   'honey',
#   'pineapple',
#   'vanilla',
#   'pasta',
#   'chicken',
#   'cheese',
#   'almond',
#   'meat',
#   'orange',
#   'grape'],
#  'soy': ['pepper',
#   'cherry',
#   'plum',
#   'blackberry',
#   'beef',
#   'spice',
#   'chocolate',
#   'leather',
#   'meat',
#   'licorice',
#   'blueberry',
#   'coffee',
#   'raspberry',
#   'teriyaki',
#   'currant',
#   'vanilla',
#   'jerky',
#   'tea',
#   'pear',
#   'berry'],
#  'strawberry': ['cherry',
#   'spice',
#   'raspberry',
#   'berry',
#   'plum',
#   'pepper',
#   'vanilla',
#   'cinnamon',
#   'chocolate',
#   'watermelon',
#   'citrus',
#   'licorice',
#   'apple',
#   'tea',
#   'jam',
#   'leather',
#   'blackberry',
#   'peach',
#   'mint',
#   'thyme'],
#  'tart': ['cherry',
#   'apple',
#   'lemon',
#   'vanilla',
#   'pineapple',
#   'spice',
#   'pear',
#   'lime',
#   'raspberry',
#   'peach',
#   'pie',
#   'plum',
#   'chocolate',
#   'berry',
#   'citrus',
#   'orange',
#   'blackberry',
#   'honey',
#   'pepper',
#   'grapefruit'],
#  'tea': ['cherry',
#   'spice',
#   'plum',
#   'berry',
#   'raspberry',
#   'lemon',
#   'pepper',
#   'blackberry',
#   'vanilla',
#   'strawberry',
#   'licorice',
#   'honey',
#   'orange',
#   'peach',
#   'chocolate',
#   'leather',
#   'cinnamon',
#   'cranberry',
#   'citrus',
#   'currant'],
#  'thyme': ['cherry',
#   'pepper',
#   'plum',
#   'raspberry',
#   'spice',
#   'sage',
#   'blackberry',
#   'berry',
#   'mint',
#   'strawberry',
#   'licorice',
#   'leather',
#   'vanilla',
#   'cranberry',
#   'cinnamon',
#   'flower',
#   'fennel',
#   'apple',
#   'lemon',
#   'beef'],
#  'tomato': ['plum',
#   'berry',
#   'cherry',
#   'spice',
#   'raspberry',
#   'pepper',
#   'grapefruit',
#   'vanilla',
#   'peach',
#   'currant',
#   'melon',
#   'citrus',
#   'tomato',
#   'leather',
#   'blackberry',
#   'olive',
#   'chocolate',
#   'licorice',
#   'coffee',
#   'mint'],
#  'truffle': ['cherry',
#   'leather',
#   'berry',
#   'spice',
#   'licorice',
#   'raspberry',
#   'pepper',
#   'plum',
#   'blackberry',
#   'cinnamon',
#   'sage',
#   'mint',
#   'flower',
#   'chocolate',
#   'meat',
#   'coffee',
#   'vanilla',
#   'ground',
#   'mocha',
#   'mushroom'],
#  'vanilla': ['cherry',
#   'spice',
#   'plum',
#   'berry',
#   'blackberry',
#   'apple',
#   'chocolate',
#   'raspberry',
#   'lemon',
#   'pepper',
#   'coffee',
#   'peach',
#   'pear',
#   'pineapple',
#   'cinnamon',
#   'licorice',
#   'mocha',
#   'citrus',
#   'cream',
#   'honey'],
#  'watermelon': ['strawberry',
#   'cherry',
#   'pink',
#   'peach',
#   'raspberry',
#   'lime',
#   'spice',
#   'salmon',
#   'berry',
#   'citrus',
#   'plum',
#   'orange',
#   'lemon',
#   'apple',
#   'melon',
#   'grapefruit',
#   'vanilla',
#   'lemonade',
#   'pomegranate',
#   'grape'],
#  'yeast': ['apple',
#   'lemon',
#   'citrus',
#   'pear',
#   'lime',
#   'spice',
#   'vanilla',
#   'pepper',
#   'grapefruit',
#   'peach',
#   'plum',
#   'cherry',
#   'melon',
#   'honey',
#   'orange',
#   'raspberry',
#   'bread',
#   'pineapple',
#   'almond',
#   'yeast']}

# %%
def save_obj(obj, name ):
    with open('data/modified/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
save_obj(flavor_cooccurences, 'flavor_combinations')

# %% [markdown]
# # Creating the elasticsearch mapping

# %%
print(flavor_cooccurences)
# Out:
# {'cherry': ['spice', 'berry', 'plum', 'raspberry', 'pepper', 'blackberry', 'vanilla', 'licorice', 'chocolate', 'leather', 'cherry', 'cinnamon', 'currant', 'coffee', 'mocha', 'mint', 'flower', 'strawberry', 'pie', 'sage'], 'berry': ['cherry', 'spice', 'plum', 'pepper', 'raspberry', 'berry', 'leather', 'licorice', 'chocolate', 'vanilla', 'blackberry', 'coffee', 'currant', 'mint', 'cinnamon', 'flower', 'mocha', 'tomato', 'olive', 'sage'], 'plum': ['cherry', 'berry', 'spice', 'blackberry', 'vanilla', 'pepper', 'raspberry', 'chocolate', 'licorice', 'plum', 'leather', 'currant', 'coffee', 'mocha', 'cinnamon', 'tomato', 'blueberry', 'mint', 'olive', 'meat'], 'apple': ['pear', 'lemon', 'citrus', 'peach', 'lime', 'apple', 'melon', 'spice', 'vanilla', 'grapefruit', 'almond', 'honey', 'flower', 'pineapple', 'apricot', 'orange', 'mousse', 'juice', 'butter', 'bread'], 'blackberry': ['cherry', 'spice', 'plum', 'chocolate', 'pepper', 'licorice', 'currant', 'berry', 'vanilla', 'jam', 'leather', 'coffee', 'blueberry', 'mocha', 'raspberry', 'blackberry', 'meat', 'cinnamon', 'mint', 'raisin'], 'vanilla': ['cherry', 'spice', 'plum', 'berry', 'blackberry', 'apple', 'chocolate', 'raspberry', 'lemon', 'pepper', 'coffee', 'peach', 'pear', 'pineapple', 'cinnamon', 'licorice', 'mocha', 'citrus', 'cream', 'honey'], 'pepper': ['cherry', 'spice', 'berry', 'blackberry', 'plum', 'raspberry', 'licorice', 'leather', 'chocolate', 'vanilla', 'currant', 'cinnamon', 'ground', 'coffee', 'meat', 'pepper', 'flower', 'mocha', 'blueberry', 'mint'], 'citrus': ['apple', 'peach', 'pear', 'lemon', 'melon', 'lime', 'grapefruit', 'spice', 'flower', 'pineapple', 'vanilla', 'honey', 'almond', 'apricot', 'citrus', 'pepper', 'cherry', 'orange', 'plum', 'grape'], 'lemon': ['apple', 'lime', 'peach', 'pear', 'citrus', 'grapefruit', 'lemon', 'vanilla', 'honey', 'pineapple', 'spice', 'apricot', 'orange', 'melon', 'almond', 'flower', 'juice', 'butter', 'pepper', 'plum'], 'raspberry': ['cherry', 'spice', 'plum', 'berry', 'pepper', 'vanilla', 'licorice', 'leather', 'cinnamon', 'blackberry', 'chocolate', 'jam', 'currant', 'strawberry', 'flower', 'mint', 'mocha', 'cranberry', 'coffee', 'tea'], 'peach': ['apple', 'citrus', 'lemon', 'pear', 'apricot', 'melon', 'lime', 'honey', 'pineapple', 'vanilla', 'flower', 'almond', 'grapefruit', 'spice', 'orange', 'peach', 'mango', 'jasmine', 'banana', 'grape'], 'pear': ['apple', 'lemon', 'peach', 'citrus', 'lime', 'melon', 'spice', 'vanilla', 'pineapple', 'apricot', 'almond', 'pear', 'honey', 'flower', 'grapefruit', 'pepper', 'orange', 'juice', 'butter', 'grape'], 'chocolate': ['cherry', 'blackberry', 'spice', 'plum', 'berry', 'vanilla', 'coffee', 'milk', 'pepper', 'licorice', 'currant', 'raspberry', 'leather', 'jam', 'blueberry', 'mocha', 'mint', 'cinnamon', 'raisin', 'chocolate'], 'currant': ['cherry', 'blackberry', 'plum', 'spice', 'berry', 'pepper', 'chocolate', 'licorice', 'raspberry', 'vanilla', 'mocha', 'leather', 'coffee', 'jam', 'meat', 'blueberry', 'beef', 'mint', 'cinnamon', 'pie'], 'licorice': ['cherry', 'spice', 'berry', 'blackberry', 'plum', 'pepper', 'leather', 'raspberry', 'chocolate', 'vanilla', 'coffee', 'currant', 'mocha', 'mint', 'cinnamon', 'sage', 'flower', 'jam', 'raisin', 'blueberry'], 'lime': ['lemon', 'apple', 'peach', 'grapefruit', 'pear', 'citrus', 'melon', 'pineapple', 'lime', 'vanilla', 'honey', 'juice', 'orange', 'apricot', 'spice', 'pepper', 'mango', 'flower', 'lychee', 'sugar'], 'coffee': ['cherry', 'plum', 'chocolate', 'berry', 'spice', 'vanilla', 'blackberry', 'licorice', 'pepper', 'mocha', 'leather', 'raspberry', 'currant', 'sage', 'coconut', 'blueberry', 'olive', 'meat', 'coffee', 'mint'], 'melon': ['apple', 'peach', 'citrus', 'pear', 'lime', 'lemon', 'grapefruit', 'spice', 'vanilla', 'pineapple', 'honey', 'apricot', 'almond', 'banana', 'orange', 'mango', 'melon', 'lychee', 'grape', 'sugar'], 'grapefruit': ['lemon', 'lime', 'citrus', 'apple', 'peach', 'pear', 'melon', 'pineapple', 'orange', 'spice', 'honey', 'apri ...

# %%
from elasticsearch import Elasticsearch
client = Elasticsearch('localhost')

# %%
mappings = {
    'mappings':{
        'flavours':{
            'properties':{
                'flavor': {'type': 'text', 'analyzer': 'english'},
                'flavor_combinations': {'type': 'text'}
            }
        }
    
}}
client.indices.create(index='findmyflavors', body=mappings)
# Out:
# {'acknowledged': True, 'index': 'findmyflavors', 'shards_acknowledged': True}

# %%
for doc_id, flavor in enumerate(flavor_cooccurences):
    client.create(index = 'findmyflavors', id=doc_id, doc_type='flavours', 
                  body={'flavor': flavor, 'flavor_combinations': flavor_cooccurences[flavor]})

# %%
query = {
            "query": {
                "match": {
                    "flavor": 'coffee'
                }
            }
        }

result = client.search(index = 'findmyflavors', body=query)

# %%
result
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '16',
#     '_index': 'findmyflavors',
#     '_score': 2.3025851,
#     '_source': {'flavor': 'coffee',
#      'flavor_combinations': ['cherry',
#       'plum',
#       'chocolate',
#       'berry',
#       'spice',
#       'vanilla',
#       'blackberry',
#       'licorice',
#       'pepper',
#       'mocha',
#       'leather',
#       'raspberry',
#       'currant',
#       'sage',
#       'coconut',
#       'blueberry',
#       'olive',
#       'meat',
#       'coffee',
#       'mint']},
#     '_type': 'flavours'}],
#   'max_score': 2.3025851,
#   'total': 1},
#  'timed_out': False,
#  'took': 3}
