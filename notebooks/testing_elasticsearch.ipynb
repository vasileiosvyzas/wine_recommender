# %%
import pandas as pd
import numpy as np
import os

from elasticsearch import Elasticsearch
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem.porter import *
from textblob import TextBlob
from textblob import Word
from collections import Counter
from nltk import word_tokenize
from nltk import sent_tokenize
from sklearn.metrics.pairwise import cosine_similarity

# %%
os.chdir('/home/fykos/Documents/workspace/wine_recommendation_system/')

# %%
wine = pd.read_csv('data/raw/winemag-data-130k-v2.csv')

# %%
wine.drop(['Unnamed: 0', 'taster_name', 'taster_twitter_handle', 'region_2'], axis=1, inplace=True)

# %%
wine.drop_duplicates(inplace=True)

# %%
wine.dropna(inplace=True)

# %%
wine['id'] = range(0, len(wine))

# %%
wine.head()
# Out:
#   country                                        description  \
# 3      US  Pineapple rind, lemon pith and orange blossom ...
# 4      US  Much like the regular bottling from 2012, this...
# 5   Spain  Blackberry and raspberry aromas show a typical...
# 6   Italy  Here's a bright, informal red that opens with ...
# 9  France  This has great depth of flavor with its fresh ...
#
#                           designation  points  price           province  \
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 9                         Les Natures      87   27.0             Alsace
#
#               region_1                                              title  \
# 3  Lake Michigan Shore  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4    Willamette Valley  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5              Navarra  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6             Vittoria   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 9               Alsace  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
#
#               variety              winery  id
# 3            Riesling          St. Julian   0
# 4          Pinot Noir        Sweet Cheeks   1
# 5  Tempranillo-Merlot              Tandem   2
# 6            Frappato     Terre di Giurfo   3
# 9          Pinot Gris  Jean-Baptiste Adam   4

# %%
wine.shape
# Out:
# (64767, 11)

# %% [markdown]
# # Loading data to ElasticSearch

# %%
client = Elasticsearch('localhost')

# %%
mappings = {
    'mappings':{
        'wines':{
            'properties':{
                'id': {'type': 'text'},
                'country': {'type':'text'},
                'description': {'type': 'text', 'analyzer': 'english'},
                'designation': {'type': 'text'},
                'points': {'type': 'float'},
                'price': {'type': 'float'},
                'province': {'type': 'text'},
                'region_1': {'type': 'text'},
                'title': {'type': 'text', 'analyzer': 'english'},
                'variety': {'type': 'text'},
                'winery': {'type': 'text'}
            }
        }
    
}}
client.indices.create(index='findmywine', body=mappings)
# Out:
# {'acknowledged': True, 'index': 'findmywine', 'shards_acknowledged': True}

# %%
docs = wine.to_dict(orient='records')

for doc_id, doc in enumerate(docs):
    client.create(index = 'findmywine', id=doc_id, doc_type='wines', body=doc)

# %% [markdown]
# # Word2Vec stuff

# %%
char_splitter = re.compile("[.,;!:()-]")

# %%
def generate_candidate_phrases(text, stopwords):
    """ generate phrases using phrase boundary markers """
 
    # generate approximate phrases with punctation
    coarse_candidates = char_splitter.split(text.lower())
 
    candidate_phrases = []
 
    for coarse_phrase in coarse_candidates:
 
        words = re.split("\\s+", coarse_phrase)
        previous_stop = False
 
        # examine each word to determine if it is a phrase boundary marker or part of a phrase or lone ranger
        for w in words:
 
            if w in stopwords and not previous_stop:
                # phrase boundary encountered, so put a hard indicator
                candidate_phrases.append(";")
                previous_stop = True
            elif w not in stopwords and len(w) > 3:
                # keep adding words to list until a phrase boundary is detected
                candidate_phrases.append(w.strip())
                previous_stop = False
 
    # get a list of candidate phrases without boundary demarcation
    phrases = re.split(";+", ' '.join(candidate_phrases))
 
    return phrases

# %%
generate_candidate_phrases(wine['description'], stopwords.words('english'))
# Out:
# ['',
#  ' deep color matches ',
#  ' bold grapy flavors ',
#  ' touch ',
#  ' sweetness soft texture ',
#  ' syrupy balance ',
#  ' chase ',
#  ' spicy burrito ',
#  ' kung chicken']

# %%
wine['description']
# Out:
# 'The deep color matches the bold grapy flavors. With a touch of sweetness, soft texture and syrupy balance, this will chase down a spicy burrito or kung pao chicken.'

# %%
def normalize(review):
    review_letters = re.sub('[^a-zA-Z]', ' ', str(review))
    review_letters = review_letters.lower()
    return (" ".join(review_letters.split()))

# %%
def remove_stopwords(review):
    stop_words = set(stopwords.words('english'))
    ls = [word for word in review.split() if word not in stop_words]
    txt = " ".join(ls)
    return (txt)

# %%
# this list is to be given as input to word2vec because is word tokenized
wine_processed_reviews = []
for review in wine['description']:
    wine_processed_reviews.append(word_tokenize(remove_stopwords(normalize(review))))

# %%
from gensim.models import Word2Vec

## Word2Vec needs a large corpus to train in order to perform well
cbow_model = Word2Vec(wine_processed_reviews, min_count = 4, size = 300, window = 8, sg=1)

# %%
similar_pork = cbow_model.wv.most_similar('pork', topn=200)
foods_similar_to_pork = [food[0] for food in similar_pork]

# %%
cbow_model.wv.most_similar('vanilla', topn=10)
# Out:
# [('macaroon', 0.6385142207145691),
#  ('copious', 0.6314226984977722),
#  ('flake', 0.619184672832489),
#  ('infusion', 0.6168062090873718),
#  ('frosting', 0.6045944690704346),
#  ('padded', 0.6019116640090942),
#  ('vanillin', 0.5998919010162354),
#  ('crumbs', 0.59284907579422),
#  ('folding', 0.592144250869751),
#  ('latte', 0.5910093784332275)]

# %%
from gensim.models.phrases import Phrases

test = Phrases(wine_processed_reviews)

# %%
test.vocab
# Out:
# defaultdict(int,
#             {b'pineapple': 1724,
#              b'rind': 461,
#              b'pineapple_rind': 6,
#              b'lemon': 4401,
#              b'rind_lemon': 3,
#              b'pith': 344,
#              b'lemon_pith': 67,
#              b'orange': 2956,
#              b'pith_orange': 2,
#              b'blossom': 764,
#              b'orange_blossom': 190,
#              b'start': 337,
#              b'blossom_start': 1,
#              b'aromas': 20924,
#              b'start_aromas': 5,
#              b'palate': 19756,
#              b'aromas_palate': 423,
#              b'bit': 3162,
#              b'palate_bit': 81,
#              b'opulent': 636,
#              b'bit_opulent': 1,
#              b'notes': 9368,
#              b'opulent_notes': 7,
#              b'honey': 2085,
#              b'notes_honey': 33,
#              b'drizzled': 38,
#              b'honey_drizzled': 8,
#              b'guava': 190,
#              b'drizzled_guava': 1,
#              b'mango': 535,
#              b'guava_mango': 9,
#              b'giving': 891,
#              b'mango_giving': 1,
#              b'way': 1360,
#              b'giving_way': 28,
#              b'slightly': 2500,
#              b'way_slightly': 4,
#              b'astringent': 792,
#              b'slightly_astringent': 36,
#              b'semidry': 34,
#              b'astringent_semidry': 1,
#              b'finish': 17410,
#              b'semidry_finish': 1,
#              b'much': 1459,
#              b'like': 4408,
#              b'much_like': 70,
#              b'regular': 206,
#              b'like_regular': 2,
#              b'bottling': 2333,
#              b'regular_bottling': 33,
#              b'comes': 1624,
#              b'bottling_comes': 13,
#              b'across': 619,
#              b'comes_across': 139,
#              b'rather': 1202,
#              b'across_rather': 2,
#              b'rough': 397,
#              b'rather_rough': 3,
#              b'tannic': 3298,
#              b'rough_tannic': 13,
#              b'rustic': 715,
#              b'tannic_rustic': 7,
#              b'earthy': 2807,
#              b'rustic_earthy': 11,
#              b'herbal': 2607,
#              b'earthy_herbal': 50,
#              b'characteristics': 250,
#              b'herbal_characteristics': 7,
#              b'nonetheless': 146,
#              b'characteristics_nonetheless': 1,
#              b'think': 137,
#              b'nonetheless_think': 1,
#              b'pleasantly': 225,
#              b'think_pleasantly': 1,
#              b'unfussy': 20,
#              b'pleasantly_unfussy': 1,
#              b'country': 103,
#              b'unfussy_country': 1,
#              b'wine': 37719,
#              b'country_wine': 10,
#              b'good': 4575,
#              b'wine_good': 249,
#              b'companion': 127,
#              b'good_companion': 16,
#              b'hearty': 431,
#              b'companion_hearty': 1,
#              b'winter': 49,
#              b'hearty_winter': 4,
#              b'stew': 52,
#              b'winter_stew': 1,
#              b'blackberry': 7105,
#              b'raspberry': 5480,
#              b'blackberry_raspberry': 90,
#              b'raspberry_aromas': 140,
#              b'show': 1841,
#              b'aromas_show': 139,
#              b'typical': 346,
#              b'show_typical': 4,
#              b'navarran': 19,
#              b'typical_navarran': 2,
#              b'whiff': 1393,
#              b'navarran_whiff': 1,
#              b'green': 4050,
#              b'whiff_green': 3,
#              b'herbs': 2323,
#              b'green_herbs': 203,
#              b'case': 167,
#              b'herbs_case': 1,
#              b'horseradish': 16,
#              b'case_horseradish': 1,
#              b'mouth': 3179,
#              b'horseradish_mouth': 1,
#              b'fairly': 554,
#              b'mouth_fairly': 6,
#              b'full': 8169,
#              b'fairly_full': 42,
#              b'bodied': 6081,
#              b'full_bodied': 3975,
#              b'tomatoey': 56,
#              b'bodied_tomatoey': 1,
#              b'acidity': 15912,
#              b'tomatoey_acidity': 13,
#              b'spicy': 3464,
#              b'acidity_spicy': 17,
#              b'spicy_herbal': 35,
#              b'flavors': 31589,
#              b'herbal_flavors': 195,
#              b'complement': 115,
#              b'flavors_complement': 14,
#              b'dark': 6442,
#              b'complement_dark': 2,
#              b'plum': 7484,
#              b'dark_plum': 227,
#              b'fruit': 24811,
#              b'plum_fruit': 225,
#              b'fruit_finish': 103,
#              b'fresh': 7659,
#              b'finish_fresh': 78,
#              b'grabby': 341,
#              b'fresh_grabby': 1,
#              b'bright': 5244,
#              b'informal': 175,
#              b'bright_informal': 4,
#              b'red': 10881,
#              b'informal_red': 20,
#              b'opens': 3144,
#              b'red_opens': 103,
#              b'opens_aromas': 971,
#              b'candied': 1428,
#              b'aromas_candied': 57,
#              b'berry': 8336,
#              b'candied_berry': 50,
#              b'white': 6252,
#              b'berry_white': 48,
#              b'pepper': 5378,
#              b'white_pepper': 1347,
#              b'savory': 2816,
#              b'pepper_savory': 13,
#              b'herb': 3708,
#              b'savory_herb': 110,
#              b'carry': 769,
#              b'herb_carry': 11,
#              b'carry_palate': 193,
#              b'balanced': 3986,
#              b'palate_balanced': 54,
#              b'balanced_fresh': 79,
#              b'fresh_acidity': 907,
#              b'soft': 6365,
#              b'acidity_soft': 120,
#              b'tannins': 14779,
#              b'soft_tannins': 432,
#              b'great': 2338,
#              b'depth': 1401,
#              b'great_depth': 64,
#              b'flavor': 3040,
#              b'depth_flavor': 116,
#              b'flavor_fresh': 9,
#              b'apple': 6608,
#              b'fresh_apple': 159,
#              b'pear': 3630,
#              b'apple_pear': 636,
#              b'fruits': 5437,
#              b'pear_fruits': 36,
#              b'touch': 4040,
#              b'fruits_touch': 66,
#              b'spice': 9720,
#              b'touch_spice': 102,
#              b'dry': 8593,
#              b'spice_dry': 21,
#              b'dry_balanced': 79,
#              b'balanced_acidity': 268,
#              b'crisp': 5927,
#              b'acidity_crisp': 140,
#              b'texture': 5982,
#              b'crisp_texture': 114,
#              b'drink': 14283,
#              b'texture_drink': 149,
#              b'supple': 1085,
#              b'soft_supple': 95,
#              b'supple_plum': 1,
#              b'envelopes': 4,
#              b'plum_envelopes': 1,
#              b'oaky': 1507,
#              b'envelopes_oaky': 1,
#              b'structure': 3330,
#              b'oaky_structure': 1,
#              b'cabernet': 6518,
#              b'structure_cabernet': 4,
#              b'supported': 305,
#              b'cabernet_supported': 1,
#              b'merlot': 3472,
#              b'supported_merlot': 3,
#              b'coffee': 2463,
#              b'merlot_coffee': 1,
#              b'chocolate': 5042,
#              b'coffee_chocolate': 100,
#              b'complete': 283,
#              b'chocolate_complete': 2,
#              b'picture': 93,
#              b'complete_picture': 21,
#              b'finishing': 784,
#              b'picture_finishing': 2,
#              b'strong': 1547,
#              b'finishing_strong': 6,
#              b'end': 1244,
#              b'strong_end': 2,
#              b'resulting': 129,
#              b'end_resulting': 1,
#              b'value': 475,
#              b'resulting_value': 1,
#              b'priced': 272,
#              b'value_priced': 41,
#              b'priced_wine': 40,
#              b'attractive': 1402,
#              b'wine_attractive': 125,
#              b'attractive_flavor': 1,
#              b'immediate': 189,
#              b'flavor_immediate': 1,
#              b'accessibility': 8,
#              b'immediate_accessibility': 4,
#              b'baked': 2066,
#              b'baked_plum': 272,
#              b'molasses': 238,
#              b'plum_molasses': 3,
#              b'balsamic': 594,
#              b'molasses_balsamic': 2,
#              b'vinegar': 69,
#              b'balsamic_vinegar': 37,
#              b'cheesy': 105,
#              b'vinegar_cheesy': 1,
#              b'oak': 10411,
#              b'cheesy_oak': 21,
#              b'oak_aromas': 171,
#              b'feed': 63,
#              b'aromas_feed': 21,
#              b'feed_palate': 1,
#              b'braced': 35,
#              b'palate_braced': 6,
#              b'bolt': 8,
#              b'braced_bolt': 1,
#              b'bolt_acidity': 4,
#              b'compact': 395,
#              b'acidity_compact': 4,
#              b'set': 709,
#              b'compact_set': 1,
#              b'saucy': 160,
#              b'set_saucy': 1,
#              b'saucy_red': 5,
#              b'red_berry': 1309,
#              b'berry_plum': 275,
#              b'plum_flavors': 640,
#              b'features': 525,
#              b'flavors_features': 5,
#              b'tobacco': 3006,
#              b'features_tobacco': 2,
#              b'peppery': 1228,
#              b'tobacco_peppery': 6,
#              b'accents': 930,
#              b'peppery_accents': 7,
#              b'accents_finish': 34,
#              b'mildly': 259,
#              b'finish_mildly': 8,
#              b'mildly_green': 19,
#              b'green_flavor': 7,
#              b'respectable': 15,
#              b'flavor_respectable': 1,
#              b'weight': 1580,
#              b'respectable_weight': 1,
#              b'balance': 2940,
#              b'weight_balance': 12,
#              b'raw': 758,
#              b'black': 15034,
#              b'raw_black': 3,
#              b'cherry': 15908,
#              b'black_cherry': 4479,
#              b'cherry_aromas': 298,
#              b'direct': 274,
#              b'aromas_direct': 6,
#              b'simple': 1719,
#              b'direct_simple': 2,
#              b'simple_good': 3,
#              b'juicy': 4256,
#              b'good_juicy': 8,
#              b'feel': 1956,
#              b'juicy_feel': 16,
#              b'thickens': 5,
#              b'feel_thickens': 1,
#              b'time': 2472,
#              b'thickens_time': 1,
#              b'time_oak': 24,
#              b'character': 3237,
#              b'oak_character': 34,
#              b'extract': 254,
#              b'character_extract': 1,
#              b'becoming': 84,
#              b'extract_becoming': 1,
#              b'apparent': 133,
#              b'becoming_apparent': 1,
#              b'apparent_flavor': 1,
#              b'profile': 444,
#              b'flavor_profile': 208,
#              b'driven': 1001,
#              b'profile_driven': 1,
#              b'driven_dark': 3,
#              b'dark_berry': 438,
#              b'berry_fruits': 826,
#              b'smoldering': 8,
#              b'fruits_smoldering': 1,
#              b'smoldering_oak': 2,
#              b'finishes': 1733,
#              b'oak_finishes': 41,
#              b'meaty': 713,
#              b'finishes_meaty': 3,
#              b'hot': 722,
#              b'meaty_hot': 1,
#              b'desiccated': 19,
#              b'desiccated_blackberry': 1,
#              b'leather': 3052,
#              b'blackberry_leather': 65,
#              b'charred': 566,
#              b'leather_charred': 2,
#              b'wood': 2582,
#              b'charred_wood': 49,
#              b'mint': 1361,
#              b'wood_mint': 7,
#              b'mint_aromas': 40,
#              b'aromas_carry': 151,
#              b'nose': 8421,
#              b'carry_nose': 19,
#              b'nose_full': 84,
#              b'bodied_tannic': 55,
#              b'heavily': 195,
#              b'tannic_heavily': 1,
#              b'oaked': 308,
#              b'heavily_oaked': 59,
#              b'tinto': 16,
#              b'oaked_tinto': 1,
#              b'fino': 34,
#              b'tinto_fino': 15,
#              b'fino_flavors': 1,
#              b'clove': 2333,
#              b'flavors_clove': 26,
#              b'woodspice': 154,
#              b'clove_woodspice': 3,
#              b'sit': 68,
#              b'woodspice_sit': 1,
#              b'top': 803,
#              b'sit_top': 15,
#              b'top_blackberry': 6,
#              b'blackberry_fruit': 325,
#              b'hickory': 132,
#              b'fruit_hickory': 5,
#              b'forceful': 72,
#              b'hickory_forceful': 1,
#              b'forceful_oak': 5,
#              b'based': 905,
#              b'oak_based': 70,
#              b'based_aromas': 19,
#              b'rise': 166,
#              b'aromas_rise': 11,
#              b'dominate': 491,
#              b'rise_dominate': 1,
#              b'dominate_finish': 21,
#              b'ripe': 12726,
#              b'ripe_aromas': 92,
#              b'aromas_dark': 202,
#              b'berries': 1192,
#              b'dark_berries': 49,
#              b'mingle': 241,
#              b'berries_mingle': 4,
#              b'ample': 601,
#              b'mingle_ample': 1,
#              b'ample_notes': 4,
#              b'notes_black': 161,
#              b'black_pepper': 1755,
#              b'toasted': 1730,
#              b'pepper_toasted': 11,
#              b'vanilla': 6269,
#              b'toasted_vanilla': 20,
#              b'dusty': 1308,
#              b'vanilla_dusty': 3,
#              b'dusty_tobacco': 4,
#              b'tobacco_palate': 22,
#              b'palate_oak': 26,
#              b'oak_driven': 221,
#              b'nature': 250,
#              b'driven_nature': 1,
#              b'nature_notes': 1,
#              b'tart': 3358,
#              b'notes_tart': 28,
#              b'tart_red': 213,
#              b'currant': 3122,
#              b'red_currant': 866,
#              b'shine': 199,
#              b'currant_shine': 2,
#              b'offering': 1388,
#              b'shine_offering': 1,
#              b'offering_bit': 1,
#              b'levity': 12,
#              b'bit_levity': 2,
#              b'delicate': 1402,
#              b'delicate_aromas': 183,
#              b'recall': 289,
#              b'aromas_recall': 200,
#              b'recall_white': 17,
#              b'flower': 1706,
#              b'white_flower': 381,
#              b'citrus': 5274,
#              b'flower_citrus': 60,
#              b'citrus_palate': 39,
#              b'offers': 6710,
#              b'palate_offers': 2325,
#              b'passion': 193,
#              b'offers_passion': 5,
#              b'passion_fruit': 189,
#              b'lime': 2562,
#              b'fruit_lime': 27,
#              b'lime_white': 26,
#              b'peach': 4104,
#              b'white_peach': 780,
#              b'hint': 2963,
#              b'peach_hint': 24,
#              b'mineral': 3177,
#              b'hint_mineral': 41,
#              b'alongside': 3079,
#              b'mineral_alongside': 118,
#              b'alongside_bright': 156,
#              b'bright_acidity': 1049,
#              b'geneseo': 1,
#              b'wine_geneseo': 1,
#              b'district': 82,
#              b'geneseo_district': 1,
#              b'district_offers': 2,
#              b'offers_aromas': 473,
#              b'sour': 1247,
#              b'aromas_sour': 11,
#              b'plums': 615,
#              b'sour_plums': 5,
#              b'enough': 1266,
#              b'plums_enough': 1,
#              b'cigar': 290,
#              b'enough_cigar': 1,
#              b'box': 233,
#              b'cigar_box': 187,
#              b'tempt': 4,
#              b'box_tempt': 1,
#              b'tempt_nose': 2,
#              b'nose_flavors': 79,
#              b'flavors_bit': 64,
#              b'flat': 396,
#              b'bit_flat': 46,
#              b'first': 1329,
#              b'flat_first': 1,
#              b'first_acidity': 1,
#              b'tension': 309,
#              b'acidity_tension': 4,
#              b'tension_sour': 2,
#              b'cherries': 2588,
#              b'sour_cherries': 31,
#              b'emerges': 66,
#              b'cherries_emerges': 1,
#              b'midpalate': 656,
#              b'emerges_midpalate': 3,
#              b'bolstered': 121,
#              b'midpalate_bolstered': 2,
#              b'bolstered_black': 5,
#              b'licorice': 3597,
#              b'black_licorice': 285,
#              b'prune': 1076,
#              b'aromas_prune': 57,
#              b'blackcurrant': 52,
#              b'prune_blackcurrant': 1,
#              b'toast': 3083,
#              b'blackcurrant_toast': 1,
#              b'toast_oak': 64,
#              b'oak_carry': 9,
#              b'extracted': 463,
#              b'carry_extracted': 1,
#              b'extracted_palate': 27,
#              b'along': 2838,
#              b'palate_along': 428,
#              b'along_flavors': 35,
#              b'flavors_black': 358,
#              b'roasted': 1569,
#              b'cherry_roasted': 23,
#              b'roasted_coffee': 280,
#              b'beans': 92,
#              b'coffee_beans': 46,
#              b'firm': 4315,
#              b'beans_firm': 1,
#              b'drying': 632,
#              b'firm_drying': 17,
#              b'drying_tannins': 194,
#              b'provide': 973,
#              b'tannins_provide': 425,
#              b'framework': 283,
#              b'provide_framework': 154,
#              b'earth': 2238,
#              b'oak_earth': 13,
#              b'intermingle': 35,
#              b'earth_intermingle': 1,
#              b'around': 1071,
#              b'intermingle_around': 4,
#              b'robust': 688,
#              b'around_robust': 5,
#              b'robust_aromas': 4,
#              b'wet': 860,
#              b'aromas_wet': 57,
#              b'forest': 893,
#              b'wet_forest': 2,
#              b'floor': 585,
#              b'forest_floor': 529,
#              b'vineyard': 4435,
#              b'floor_vineyard': 2,
#              b'designated': 134,
#              b'vineyard_designated': 88,
#              b'pinot': 3836,
#              b'designated_pinot': 3,
#              b'hails': 87,
#              b'pinot_hails': 1,
#              b'high': 2372,
#              b'hails_high': 3,
#              b'elevation': 128,
#              b'high_elevation': 68,
#              b'site': 542,
#              b'elevation_site': 17,
#              b'small': 674,
#              b'site_small': 2,
#              b'production': 334,
#              b'small_production': 101,
#              b'production_offers': 1,
#              b'intense': 1956,
#              b'offers_intense': 31,
#              b'intense_full': 14,
#              b'bodied_raspberry': 2,
#              b'raspberry_blackberry': 78,
#              b'steeped': 69,
#              b'blackberry_steeped': 1,
#              b'smoky': 2326,
#              b'steeped_smoky': 2,
#              b'smoky_spice': 14,
#              b'smooth': 3429,
#              b'spice_smooth': 31,
#              b'smooth_texture': 277,
#              b'pretty': 1702,
#              b'pretty_aromas': 105,
#              b'yellow': 1971,
#              b'aromas_yellow': 90,
#              b'yellow_flower': 89,
#              b'stone': 2023,
#              b'flower_stone': 43,
#              b'stone_fruit': 1176,
#              b'lead': 2811,
#              b'fruit_lead': 129,
#              b'lead_nose': 870,
#              b'nose_bright': 51,
#              b'bright_palate': 157,
#              b'offers_yellow': 72,
#              b'yellow_apple': 435,
#              b'apricot': 1803,
#              b'apple_apricot': 39,
#              b'apricot_vanilla': 27,
#              b'vanilla_delicate': 1,
#              b'delicate_notes': 18,
#              b'lightly': 1666,
#              b'notes_lightly': 3,
#              b'lightly_toasted': 58,
#              b'toasted_oak': 579,
#              b'oak_alongside': 32,
#              b'alongside_crisp': 82,
#              b'crisp_acidity': 1075,
#              b'suggest': 669,
#              b'aromas_suggest': 220,
#              b'mature': 1539,
#              b'suggest_mature': 3,
#              b'mature_berry': 89,
#              b'scorched': 253,
#              b'berry_scorched': 21,
#              b'scorched_earth': 194,
#              b'animal': 181,
#              b'earth_animal': 5,
#              b'animal_toast': 1,
#              b'anise': 1577,
#              b'toast_anise': 3,
#              b'anise_palate': 6,
#              b'offers_ripe': 195,
#              b'ripe_black': 743,
#              b'black_berry': 99,
#              b'berry_oak': 30,
#              b'espresso': 1446,
#              b'oak_espresso': 77,
#              b'cocoa': 926,
#              b'espresso_cocoa': 6,
#              b'cocoa_vanilla': 33,
#              b'vanilla_alongside': 81,
#              b'alongside_dusty': 22,
#              b'dusty_tannins': 272,
#              b'rustic_dry': 8,
#              b'dry_flavors': 83,
#              b'flavors_berries': 39,
#              b'currants': 1231,
#              b'berries_currants': 27,
#              b'currants_licorice': 42,
#              b'spices': 1832,
#              b'licorice_spices': 4,
#              b'made': 4012,
#              b'spices_made': 4,
#              b'made_cabernet': 138,
#              b'franc': 1841,
#              b'cabernet_franc': 1557,
#              b'franc_cabernet': 102,
#              b'sauvignon': 4430,
#              b'cabernet_sauvignon': 3370,
#              b'many': 769,
#              b'erath': 20,
#              b'many_erath': 2,
#              b'erath_vineyard': 1,
#              b'designates': 40,
#              b'vineyard_designates': 28,
#              b'strongly': 337,
#              b'designates_strongly': 1,
#              b'strongly_herbal': 22,
#              b'herbal_notes': 191,
#              b'leaf': 754,
#              b'notes_leaf': 6,
#              b'leaf_herb': 23,
#              b'create': 219,
#              b'herb_create': 1,
#              b'somewhat': 772,
#              b'create_somewhat': 3,
#              b'unripe': 130,
#              b'somewhat_unripe': 3,
#              b'unripe_flavor': 1,
#              b'impressions': 35,
#              b'flavor_impressions': 3,
#              b'impressions_touch': 1,
#              b'bitterness': 430,
#              b'touch_bitterness': 44,
#              b'bitterness_finish': 59,
#              b'finish_fruit': 34,
#              b'passes': 14,
#              b'fruit_passes': 1,
#              b'ripeness': 848,
#              b'passes_ripeness': 1,
#              b'sweet': 6654,
#              b'ripeness_sweet': 5,
#              b'tomatoes': 30,
#              b'sweet_tomatoes': 1,
#              b'concentrated': 3017,
#              b'concentrated_cabernet': 9,
#              b'cabernet_offers': 11,
#              b'cured': 322,
#              b'aromas_cured': 40,
#              b'meat': 1318,
#              b'cured_meat': 239,
#              b'dried': 4662,
#              b'meat_dried': 13,
#              b'dried_fruit': 198,
#              b'rosemary': 278,
#              b'fruit_rosemary': 1,
#              b'barbecue': 339,
#              b'rosemary_barbecue': 1,
#              b'barbecue_spice': 22,
#              b'teriyaki': 86,
#              b'spice_teriyaki': 4,
#              b'sauce': 494,
#              b'teriyaki_sauce': 15,
#              b'sauce_flavors': 20,
#              b'give': 2768,
#              b'flavors_give': 160,
#              b'give_wine': 364,
#              b'bold': 1290,
#              b'wine_bold': 41,
#              b'chewy': 1117,
#              b'bold_chewy': 6,
#              b'chewy_feel': 14,
#              b'inky': 286,
#              b'color': 2364,
#              b'inky_color': 29,
#              b'color_wine': 147,
#              b'plump': 665,
#              b'wine_plump': 10,
#              b'plump_aromas': 18,
#              b'aromas_ripe': 417,
#              b'ripe_fruit': 846,
#              b'fruit_blackberry': 64,
#              b'jam': 1463,
#              b'blackberry_jam': 477,
#              b'rum': 81,
#              b'jam_rum': 1,
#              b'cake': 489,
#              b'rum_cake': 67,
#              b'cake_palate': 5,
#              b'palate_soft': 111,
#              b'soft_smooth': 110,
#              b'part': 375,
#              b'natural': 437,
#              b'part_natural': 4,
#              b'natural_wine': 12,
#              b'movement': 15,
#              b'wine_movement': 9,
#              b'movement_wine': 1,
#              b'wine_made': 501,
#              b'organic': 182,
#              b'made_organic': 35,
#              b'grapes': 1651,
#              b'organic_grapes': 60,
#              b'label': 349,
#              b'grapes_label': 1,
#              b'printed': 4,
#              b'label_printed': 1,
#              b'vegetable': 44,
#              b'printed_vegetable': 1,
#              b'ink': 23,
#              b'vegetable_ink': 1,
#              b'recycled': 1,
#              b'ink_recycled': 1,
#              b'paper': 12,
#              b'recycled_paper': 1,
#              b'quality': 1117,
#              b'paper_quality': 1,
#              b'quality_fruit': 67,
#              b'nice': 1302,
#              b'fruit_nice': 13,
#              b'nice_juicy': 3,
#              b'juicy_palate': 309,
#              b'palate_bright': 88,
#              b'bright_berry': 109,
#              b'berry_flavor': 56,
#              b'flavor_finish': 51,
#              b'festive': 10,
#              b'festive_wine': 1,
#              b'wine_soft': 368,
#              b'soft_ripe': 147,
#              b'fruit_acidity': 204,
#              b'plus': 385,
#              b'acidity_plus': 4,
#              b'plus_red': 1,
#              b'right': 1203,
#              b'starting': 181,
#              b'right_starting': 1,
#              b'blocks': 91,
#              b'starting_blocks': 1,
#              b'blocks_oaky': 1,
#              b'oaky_wine': 39,
#              b'dripping': 22,
#              b'wine_dripping': 2,
#              b'caramel': 1385,
#              b'dripping_caramel': 2,
#              b'caramel_vanilla': 63,
#              b'vanilla_notes': 118,
#              b'notes_texture': 11,
#              b'texture_midpalate': 7,
#              b'finessed': 29,
#              b'midpalate_finessed': 1,
#              b'graceful': 119,
#              b'finessed_graceful': 1,
#              b'graceful_drying': 1,
#              b'latch': 4,
#              b'tannins_latch': 2,
#              b'onto': 223,
#              b'latch_onto': 4,
#              b'onto_oak': 1,
#              b'driven_finish': 37,
#              b'eccentric': 30,
#              b'finish_eccentric': 1,
#              b'blend': 7993,
#              b'eccentric_blend': 2,
#              b'tannat': 157,
#              b'blend_tannat': 17,
#              b'petit': 1258,
#              b'tannat_petit': 8,
#              b'verdot': 1212,
#              b'petit_verdot': 1191,
#              b'pinotage': 13,
#              b'verdot_pinotage': 1,
#              b'spicy_fresh': 11,
#              b'clean': 2509,
#              b'fresh_clean': 111,
#              b'would': 924,
#              b'clean_would': 1,
#              b'pair': 1102,
#              b'would_pair': 284,
#              b'fried': 73,
#              b'pair_fried': 11,
#              b'seafood': 159,
#              b'fried_seafood': 3,
#              b'spaghetti': 17,
#              b'seafood_spaghetti': 1,
#              b'con': 17,
#              b'spaghetti_con': 6,
#              b'vongole': 8,
#              b'con_vongole': 5,
#              b'vongole_offers': 1,
#              b'offers_pretty': 41,
#              b'pretty_citrus': 3,
#              b'tones': 1325,
#              b'citrus_tones': 9,
#              b'followed': 1408,
#              b'tones_followed': 9,
#              b'followed_drying': 3,
#              b'drying_mineral': 66,
#              b'nuance': 218,
#              b'mineral_nuance': 4,
#              b'fruity': 3859,
#              b'soft_fruity': 139,
#              b'generous': 1657,
#              b'fruity_generous': 9,
#              b'generous_ripe': 46,
#              b'ripe_wine': 474,
#              b'wine_full': 535,
#              b'full_juicy': 30,
#              b'juicy_red': 241,
#              b'red_cherry': 1306,
#              b'cherry_fruits': 109,
#              b'gentle': 491,
#              b'fruits_gentle': 16,
#              b'gentle_tannins': 58,
#              b'richness': 2260,
#              b'tannins_richness': 6,
#              b'richness_giving': 3,
#              b'giving_sweet': 3,
#              b'sweet_character': 10,
#              b'open': 850,
#              b'character_open': 4,
#              b'ready': 2072,
#              b'open_ready': 10,
#              b'ready_drink': 1656,
#              b'drink_wine': 239,
#              b'monica': 6,
#              b'grape': 1375,
#              b'monica_grape': 1,
#              b'often': 228,
#              b'grape_often': 6,
#              b'shows': 6215,
#              b'often_shows': 4,
#              b'shows_rustic': 7,
#              b'rustic_raw': 3,
#              b'raw_quality': 8,
#              b'quality_aromas': 4,
#              b'aromas_cherry': 199,
#              b'cola': 2555,
#              b'cherry_cola': 432,
#              b'cola_black': 58,
#              b'pepper_sour': 4,
#              b'sour_fruit': 17,
#              b'expression': 1013,
#              b'fruit_expression': 18,
#              b'added': 242,
#              b'expression_added': 1,
#              b'added_touch': 3,
#              b'touch_bright': 3,
#              b'acidity_finish': 184,
#              b'fruity_lightly': 26,
#              b'herbaceous': 243,
#              b'lightly_herbaceous': 8,
#              b'fine': 3591,
#              b'herbaceous_fine': 1,
#              b'textured': 1392,
#              b'fine_textured': 8,
#              b'textured_acidity': 20,
#              b'acidity_along': 44,
#              b'pink': 924,
#              b'along_pink': 4,
#              b'grapefruit': 1574,
#              b'pink_grapefruit': 270,
#              b'grapefruit_flavor': 16,
#              b'flavor_wine': 58,
#              b'wine_bright': 202,
#              b'easy': 2140,
#              b'bright_easy': 16,
#              b'easy_ready': 6,
#              b'months': 935,
#              b'drink_months': 6,
#              b'jelly': 103,
#              b'shows_jelly': 1,
#              b'jelly_like': 1,
#              b'like_flavors': 81,
#              b'flavors_orange': 90,
#              b'orange_pear': 20,
#              b'pear_earthy': 3,
#              b'earthy_tones': 30,
#              b'mouthfeel': 2464,
#              b'tones_mouthfeel': 3,
#              b'mouthfeel_soft': 60,
#              b'bounty': 11,
#              b'soft_bounty': 1,
#              b'bounty_oak': 1,
#              b'form': 370,
#              b'oak_form': 4,
#              b'buttered': 787,
#              b'form_buttered': 11,
#              b'buttered_toast': 544,
#              b'toast_caramel': 76,
#              b'caramel_notes': 27,
#              b'touch_toasted': 14,
#              b'almond': 1613,
#              b'toasted_almond': 221,
#              b'almond_start': 2,
#              b'grillo': 50,
#              b'start_grillo': 1,
#              b'revs': 3,
#              b'grillo_revs': 1,
#              b'glass': 1750,
#              b'revs_glass': 2,
#              b'deliver': 121,
#              b'glass_deliver': 2,
#              b'deliver_notes': 2,
#              b'notes_citrus': 53,
#              b'citrus_stone': 86,
#              b'crushed': 1742,
#              b'fruit_crushed': 30,
#              b'crushed_stone': 148,
#              b'stone_lemon': 9,
#              b'lemon_tart': 18,
#              b'tart_mouthfeel': 6,
#              b'mouthfeel_crisp': 11,
#              b'crisp_simple': 5,
#              b'syrupy': 339,
#              b'dense': 2417,
#              b'syrupy_dense': 3,
#              b'dense_wine': 151,
#              b'jammy': 1527,
#              b'wine_jammy': 36,
#              b'jammy_plum': 13,
#              b'plum_vanilla': 102,
#              b'indeterminate': 4,
#              b'vanilla_indeterminate': 1,
#              b'indeterminate_structure': 1,
#              b'plenty': 1678,
#              b'structure_plenty': 9,
#              b'plenty_oak': 47,
#              b'oak_ripe': 48,
#              b'ripe_full': 308,
#              b'bodied_accents': 1,
#              b'graphite': 775,
#              b'accents_graphite': 2,
#              b'graphite_leather': 6,
#              b'densely': 216,
#              b'hued': 54,
#              b'densely_hued': 1,
#              b'hued_wine': 19,
#              b'wine_aromas': 212,
#              b'aromas_black': 514,
#              b'black_plum': 1012,
#              b'vanilla_carry': 9,
#              b'carry_simple': 8,
#              b'simple_palate': 95,
#              b'along_touch': 29,
#              b'cedar': 1772,
#              b'touch_cedar': 16,
#              b'pliant': 29,
#              b'cedar_pliant': 1,
#              b'pliant_tannins': 15,
#              b'tannins_give': 387,
#              b'easygoing': 398,
#              b'give_easygoing': 1,
#              b'easygoing_nature': 3,
#              b'nature_drink': 4,
#              b'soon': 759,
#              b'drink_soon': 356,
#              b'brooding': 474,
#              b'aromas_brooding': 21,
#              b'brooding_notes': 38,
#              b'barrel': 2055,
#              b'notes_barrel': 16,
#              b'barrel_spice': 224,
#              b'spice_cherry': 57,
#              b'cherry_flavors': 1131,
#              b'flavors_tart': 133,
#              b'elegant': 2739,
#              b'tart_elegant': 8,
#              b'style': 3398,
#              b'elegant_style': 57,
#              b'style_lightly': 7,
#              b'gritty': 413,
#              b'lightly_gritty': 8,
#              b'gritty_tannins': 68,
#              b'backing': 59,
#              b'tannins_backing': 29,
#              ...})

# %% [markdown]
# # Quering Elasticsearch

# %%
query = {
    'query':{
        'match_all':{}
    }
}

result = client.search(index = 'findmywine', body=query)

# %%
result
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '40',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'US',
#      'description': 'This is made from equal parts Cabernet Franc and Merlot, with small additions of Malbec. Juicy, it reveals a raisiny quality of ripeness around integrated oak and generous tannin.',
#      'designation': 'The Cypher',
#      'id': 40,
#      'points': 86,
#      'price': 75.0,
#      'province': 'California',
#      'region_1': 'Napa Valley',
#      'title': 'Mulvane Wine Co. 2013 The Cypher Red (Napa Valley)',
#      'variety': 'Bordeaux-style Red Blend',
#      'winery': 'Mulvane Wine Co.'},
#     '_type': 'wines'},
#    {'_id': '41',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'Australia',
#      'description': 'This medium-bodied Chardonnay features aromas of pineapple and roasted cashew. Similar notes of ripe pineapple and nuts mark the palate, then ease to a rather soft, easy finish. Drink now.',
#      'designation': 'Made With Organic Grapes',
#      'id': 41,
#      'points': 86,
#      'price': 18.0,
#      'province': 'South Australia',
#      'region_1': 'South Australia',
#      'title': 'Yalumba 2016 Made With Organic Grapes Chardonnay (South Australia)',
#      'variety': 'Chardonnay',
#      'winery': 'Yalumba'},
#     '_type': 'wines'},
#    {'_id': '44',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'Australia',
#      'description': "Pale copper in hue, this wine exudes passion fruit on the nose, while the palate delivers nuances of muskmelon as well. It's crisp, racy and medium in body, perfectly suited to summertime refreshment. Drink now.",
#      'designation': 'Jester Sangiovese',
#      'id': 44,
#      'points': 86,
#      'price': 20.0,
#      'province': 'South Australia',
#      'region_1': 'McLaren Vale',
#      'title': 'Mitolo 2016 Jester Sangiovese Rosé (McLaren Vale)',
#      'variety': 'Rosé',
#      'winery': 'Mitolo'},
#     '_type': 'wines'},
#    {'_id': '48',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'US',
#      'description': "This blend of Sangiovese, Malbec, Cabernet Sauvignon, Petite Sirah and other varieties plays well to type. It shows a wealth of ripe, dusty black fruit that's richly round and soft on the palate, approachable and lightly oaked.",
#      'designation': 'Siena',
#      'id': 48,
#      'points': 88,
#      'price': 23.0,
#      'province': 'California',
#      'region_1': 'Sonoma County',
#      'title': 'Ferrari-Carano 2014 Siena Red (Sonoma County)',
#      'variety': 'Red Blend',
#      'winery': 'Ferrari-Carano'},
#     '_type': 'wines'},
#    {'_id': '52',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'Italy',
#      'description': 'Forest floor, menthol, espresso, cranberry and pressed violet aromas take shape in the glass. The lean linear palate shows dried sour cherry, licorice and coffee bean alongside assertive close-grained tannins. Even though the tannins are still firm, drink sooner rather than later to capture the remaining fruit.',
#      'designation': 'Dono Riserva',
#      'id': 52,
#      'points': 88,
#      'price': 30.0,
#      'province': 'Tuscany',
#      'region_1': 'Morellino di Scansano',
#      'title': 'Serpaia di Endrizzi 2010 Dono Riserva  (Morellino di Scansano)',
#      'variety': 'Sangiovese',
#      'winery': 'Serpaia di Endrizzi'},
#     '_type': 'wines'},
#    {'_id': '60',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'US',
#      'description': 'Lots of spearmint, coyote mint, hot licorice, ginger snaps and Dr Pepper spice up the strawberry fruit of this wine that provides a very herbal take on the grape. Oregano, marjoram, thyme and dill all make a showing on the sip, against a backbone of sweet cherry and blackberry fruit, finishing on cedar.',
#      'designation': 'J.D. Hurley',
#      'id': 60,
#      'points': 87,
#      'price': 26.0,
#      'province': 'California',
#      'region_1': 'Santa Clara Valley',
#      'title': 'Martin Ranch 2014 J.D. Hurley Zinfandel (Santa Clara Valley)',
#      'variety': 'Zinfandel',
#      'winery': 'Martin Ranch'},
#     '_type': 'wines'},
#    {'_id': '73',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'US',
#      'description': "Defines Rockpile Zinfandel in intensity of fruit and high alcohol which is in keeping with the volume. There are few red wines in the world like this. It's fully dry, with potent flavors of baked blackberries, blackcurrants, cola and peppery spices, and the tannins are huge, but negotiable. Demands the richest grilled meats and cheeses.",
#      'designation': 'Rockpile Cemetary Vineyard',
#      'id': 73,
#      'points': 92,
#      'price': 39.0,
#      'province': 'California',
#      'region_1': 'Rockpile',
#      'title': 'Mauritson 2007 Rockpile Cemetary Vineyard Zinfandel (Rockpile)',
#      'variety': 'Zinfandel',
#      'winery': 'Mauritson'},
#     '_type': 'wines'},
#    {'_id': '79',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'Italy',
#      'description': 'The color is just beginning to show signs of browning at the edge, but the wine is still fresh and vibrant. The nose is complex, showing licorice, summer fruits, caramel and roses. On the palate, it is soft and pleasant, but lacks some concentration.  At its peak, but will drink well for a few years.',
#      'designation': 'Sorano',
#      'id': 79,
#      'points': 91,
#      'price': 60.0,
#      'province': 'Piedmont',
#      'region_1': 'Barolo',
#      'title': 'Giacomo Ascheri 2001 Sorano  (Barolo)',
#      'variety': 'Nebbiolo',
#      'winery': 'Giacomo Ascheri'},
#     '_type': 'wines'},
#    {'_id': '84',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'France',
#      'description': 'Rich gold in color. Broad, layered aromas of very ripe fruit with hints of sweet smoke, brown sugar, honey and a savory earthy minerality. Full-bodied, bone dry, but richly textured with crisp acidity and a wide palette of flavors, ripe stone fruit, a creamy savory earthiness, sage and a balsamic kick on the finish. Very long length, slightly warm but with a lingering savory, mineral finish.',
#      'designation': 'Hunawihr Clos Windsbuhl',
#      'id': 84,
#      'points': 90,
#      'price': 84.0,
#      'province': 'Alsace',
#      'region_1': 'Alsace',
#      'title': 'Domaine Zind-Humbrecht 2007 Hunawihr Clos Windsbuhl Pinot Gris (Alsace)',
#      'variety': 'Pinot Gris',
#      'winery': 'Domaine Zind-Humbrecht'},
#     '_type': 'wines'},
#    {'_id': '89',
#     '_index': 'findmywine',
#     '_score': 1.0,
#     '_source': {'country': 'US',
#      'description': "Smashed blackberry and blueberry fruit are enhanced by burned caramel, heavy slate and touches of soy and smoke on the nose. There's great depth in both body and flavors once sipped, with a layer of fine-grained tannins revealing teriyaki, black plum, boysenberry and touches of lavender.",
#      'designation': 'Destruction Level',
#      'id': 89,
#      'points': 91,
#      'price': 35.0,
#      'province': 'California',
#      'region_1': 'Monterey',
#      'title': 'Wrath 2013 Destruction Level Red (Monterey)',
#      'variety': 'Rhône-style Red Blend',
#      'winery': 'Wrath'},
#     '_type': 'wines'}],
#   'max_score': 1.0,
#   'total': 64767},
#  'timed_out': False,
#  'took': 14}

# %%
wines = []
for hit in result['hits']['hits']:
    wine = hit['_source']
    wine['id'] = hit['_id']
    wines.append(wine)

# %%
query = {
    'query':{
            'match':{
                'region_1': 'Sonoma Valley'
            }
    }
}

result = client.search(index = 'findmywine', body=query)

# %%
result
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '101',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': "Black as a moonless night, dense in structure, tannic, bone dry and super-peppery, this Syrah isn't offering much relief right now. In all likelihood it will emerge from its cocoon in a few years to offer a wealth of ripe blackberry, currant and carob fruit.",
#      'designation': 'Jack London Vineyard',
#      'id': 101,
#      'points': 88,
#      'price': 25.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Kenwood 2005 Jack London Vineyard Syrah (Sonoma Valley)',
#      'variety': 'Syrah',
#      'winery': 'Kenwood'},
#     '_type': 'wines'},
#    {'_id': '738',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': "There's a minty, ammonia streak of greenness that can charitably be described as gooseberry in this dry Sauvignon Blanc. Oak brings sweet vanilla richness, but the wine is still pretty eccentric.",
#      'designation': 'Estate Grown',
#      'id': 738,
#      'points': 84,
#      'price': 24.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Petroni 2010 Estate Grown Sauvignon Blanc (Sonoma Valley)',
#      'variety': 'Sauvignon Blanc',
#      'winery': 'Petroni'},
#     '_type': 'wines'},
#    {'_id': '1227',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': "Here's a lusty, rugged Zinfandel marked by strong, superripe flavors. The blackberries and plums veer into currants and raisins, and finish spicy and dry, while enormously high alcohol gives the impression of heat. But that's Zinfandel for you. Needs a grilled flank steak to play against.",
#      'designation': 'Rowe Vineyard Old Vines',
#      'id': 1227,
#      'points': 87,
#      'price': 40.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'St. Francis 2007 Rowe Vineyard Old Vines Zinfandel (Sonoma Valley)',
#      'variety': 'Zinfandel',
#      'winery': 'St. Francis'},
#     '_type': 'wines'},
#    {'_id': '1695',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': "Here's a Cab that needs food to round it off and polish its rough edges. Very dry and a bit angular in tannins, with a peppery bite and generous flavors of cherries and blackberries.",
#      'designation': 'Heritage Reserve',
#      'id': 1695,
#      'points': 89,
#      'price': 50.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Schug 2004 Heritage Reserve Cabernet Sauvignon (Sonoma Valley)',
#      'variety': 'Cabernet Sauvignon',
#      'winery': 'Schug'},
#     '_type': 'wines'},
#    {'_id': '2197',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': 'This wine combines 42% Merlot with 30% Cabernet Sauvignon, 23% Malbec and 5% Cabernet Franc. It is inviting in juicy red berry and currant, with accents of lavender and herb. Full figured, it offers additionally compelling layers of subtle spice before a focused finish.',
#      'designation': 'Paysage Estate Grown',
#      'id': 2197,
#      'points': 90,
#      'price': 62.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Lasseter 2012 Paysage Estate Grown Red (Sonoma Valley)',
#      'variety': 'Bordeaux-style Red Blend',
#      'winery': 'Lasseter'},
#     '_type': 'wines'},
#    {'_id': '1782',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': "With the '05, Bucklin is getting a handle on this old-vine field blend of two dozen varieties, which seems to do best in cooler years. It's a rustic-chic wine, with a brawny muscularity tamed by extreme dryness, and even though the alcohol is 15.6%, it doesn't feel too hot.",
#      'designation': 'Old Hill Ranch',
#      'id': 1782,
#      'points': 87,
#      'price': 34.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Bucklin 2005 Old Hill Ranch Zinfandel (Sonoma Valley)',
#      'variety': 'Zinfandel',
#      'winery': 'Bucklin'},
#     '_type': 'wines'},
#    {'_id': '2743',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': 'This sultry, big-boned wine offers deft aspects of black pepper and dried herb atop a softly layered touch of brown sugar. Richness is there, as is a voluptuous flirtatiousness, yet it remains dry and dusty on the palate and classically varietal.',
#      'designation': 'Indian Springs Ranch Reserve',
#      'id': 2743,
#      'points': 92,
#      'price': 34.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Haraszthy 2013 Indian Springs Ranch Reserve Zinfandel (Sonoma Valley)',
#      'variety': 'Zinfandel',
#      'winery': 'Haraszthy'},
#     '_type': 'wines'},
#    {'_id': '3301',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': 'Fuzzy stone fruit from apricot to peach dominate on the nose and palate in this straightforward, creamy and richer-styled wine. Batches of apple and lemon give it a crisp edge toward the middle before denser crème brûlée and vanilla take over on the finish.',
#      'designation': 'Comfort Wine',
#      'id': 3301,
#      'points': 85,
#      'price': 22.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Custard 2013 Comfort Wine Chardonnay (Sonoma Valley)',
#      'variety': 'Chardonnay',
#      'winery': 'Custard'},
#     '_type': 'wines'},
#    {'_id': '5168',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': 'Powerful black cherry and blackberry aromas and flavors seem to infuse this full-bodied wine with lots of fruit energy. It tastes vivid and unique because of that deep vein of black fruit impressions, and stays balanced by firm acidity and fine-grained tannins in spite of its alcoholic strength.',
#      'designation': 'Fighting Brothers Cuvée',
#      'id': 5168,
#      'points': 90,
#      'price': 38.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Saxon Brown 2010 Fighting Brothers Cuvée Zinfandel (Sonoma Valley)',
#      'variety': 'Zinfandel',
#      'winery': 'Saxon Brown'},
#     '_type': 'wines'},
#    {'_id': '4727',
#     '_index': 'findmywine',
#     '_score': 4.8111386,
#     '_source': {'country': 'US',
#      'description': 'Distinctive as always, this is another powerful Zinfandel from Martini, which has a long history with this mountain vineyard. The cool 2010 vintage was kind, bringing the wine to its usual high-alcohol superripeness, yet maintaining vital acidity. Notes of raisins, blackberry jam and chocolate are all found in this heady, Porty wine. Drink now with rich barbecue and stews.',
#      'designation': 'Monte Rosso Vineyard Gnarly Vine',
#      'id': 4727,
#      'points': 89,
#      'price': 50.0,
#      'province': 'California',
#      'region_1': 'Sonoma Valley',
#      'title': 'Louis M. Martini 2010 Monte Rosso Vineyard Gnarly Vine Zinfandel (Sonoma Valley)',
#      'variety': 'Zinfandel',
#      'winery': 'Louis M. Martini'},
#     '_type': 'wines'}],
#   'max_score': 4.8111386,
#   'total': 17640},
#  'timed_out': False,
#  'took': 11}

# %%
wines = []
i = 0
for hit in result['hits']['hits']:
    if i < 30:
        wine = hit['_source']
        print (wine['description'], ' ---> ', [word for word in foods_similar_to_pork if word in wine['description']])
        print()
        i+=1
    else:
        break
# Out:
# Unique aromas of chamomile, dried orange peel, hay and smoked chicken show on the nose of this bottling. The palate is also a wash of intrigue, with smoked lemon peels, roasting chicken, oregano and other dried herbs.  --->  ['roast', 'chicken', 'ham', 'roasting', 'smoked', 'tri']
#
# The grapes come from the Chicken Dinner vineyard, which says it all. Pop this tart, tangy wine, with its Zin-like red berry flavors and hints of white pepper, and bring on the fried chicken. —P.G.  --->  ['chicken', 'fried']
#
# A rugged, simple wine, with raspberry, cherry and spice flavors. Drink it with everyday fare, like burgers or chicken tacos.  --->  ['chicken', 'burgers', 'tacos', 'fare']
#
# A Chardonnay with noticeable barrel influence, this is creamy and thick, with a baked apple flavor. Pair it with chicken in cream sauce or lobster and butter.  --->  ['chicken', 'sauce', 'lobster']
#
# This fresh and easy Sicilian white is a blend of Insolia, Grecanico and Catarratto with easy citrus and stone fruit aromas. Pair it with Chinese chicken salad.  --->  ['chicken']
#
# Esterlina's Dry offering is smooth, crisp and yes, dry, with a lot of light lemon scents and flavors. Would pair well with seafood or lemony chicken.  --->  ['chicken', 'seafood', 'pair']
#
# This is a pretty nice Merlot, soft, smooth and rich in oak-accented cherry pie flavor. It finishes a little sweet; try pairing it with teriyaki chicken or pork.  --->  ['chicken', 'teriyaki', 'pairing', 'pair']
#
# This blend of Nero d'Avola and Frappato delivers a tight, compact mouthfeel, with lively aromas of forest berry, blueberry and white almond. Pair it with roast chicken or pork.  --->  ['roast', 'chicken', 'deli']
#
# A good, somewhat rustic Merlot, with cherry liqueur, sweet tobacco and white pepper flavors. Drink this pleasant wine now with a nice roast chicken.  --->  ['roast', 'chicken']
#
# The deep color matches the bold grapy flavors. With a touch of sweetness, soft texture and syrupy balance, this will chase down a spicy burrito or kung pao chicken.  --->  ['chicken', 'match']

# %%
query = {
    'query':{
            'terms':{
                'description': foods_similar_to_pork
            }
    }
}

result = client.search(index = 'findmywine', body=query)

# %%
wines = []
i = 0
for hit in result['hits']['hits']:
    if i < 30:
        wine = hit['_source']
        print (wine['description'], ' ---> ', [word for word in foods_similar_to_pork if word in wine['description']])
        print()
        i+=1
    else:
        break
# Out:
# Black plum, cola and chocolate define this textbook Malbec. The wine has body, heft and lots of fruit, but also some complexity and character. Flavors of black cherry, plum and cassis are layered and fairly boisterous, while the mouthfeel is firm and just slightly tannic. Just right for red meats and pastas.  --->  ['meats', 'pasta', 'pastas', 'jus', 'meat']
#
# This blend of Incrocio Manzoni and Vermentino opens with bold floral intensity, plus solid background tones of peach and lemon mousse. It offers a creamy, soft mouthfeel that could stand up to white meat or shellfish.  --->  ['fish', 'shellfish', 'meat']
#
# Great now with lamb, this Pinot is softly complex and forward in fruit, with a silky texture. It shows cherry, raspberry, mocha, anise and smoky oak flavors. Best now and for a few more years.  --->  ['lamb']
#
# More tannic, drier and more acidic than most fine coastal Syrahs, this one from the Sierra Foothills is marked by its firm structure.The black currant, licorice, beef jerky and tobacco flavors are complex. Best now.  --->  ['beef', 'jerky', 'rice']
#
# The winery's characteristic dense style is immediately apparent in this blend of 54% Syrah, 21% Mourvèdre, 16% Grenache and 9% Petite Sirah. It offers black licorice, smoked meat, baked black cherry and graphite aromas, needing time to breathe before unleashing black coffee, elderberry jam, asphalt and charcoal flavors through tarry tannins. Drink 2018–2028.  --->  ['meat', 'rice', 'smoked']
#
# Rich and full, this has aromas of cherry, toasted nut, spice and chocolate. Its persistency would pair with roast pork stuffed with prunes.  --->  ['roast', 'stuffed', 'pair']
#
# Defines Rockpile Zinfandel in intensity of fruit and high alcohol which is in keeping with the volume. There are few red wines in the world like this. It's fully dry, with potent flavors of baked blackberries, blackcurrants, cola and peppery spices, and the tannins are huge, but negotiable. Demands the richest grilled meats and cheeses.  --->  ['meats', 'cheese', 'grill', 'cheeses', 'pot', 'meat']
#
# Smashed blackberry and blueberry fruit are enhanced by burned caramel, heavy slate and touches of soy and smoke on the nose. There's great depth in both body and flavors once sipped, with a layer of fine-grained tannins revealing teriyaki, black plum, boysenberry and touches of lavender.  --->  ['veal', 'teriyaki', 'soy']
#
# Dark and thick in the glass, this wine shows strong but not bitter tar notes on the nose plus charred beef in a blueberry glaze, wet campfire, bourbon barrel and vanilla. The structure is massive now, gooey with thick tannins and flavors of espresso bean and condensed purple flowers. Judicious acidity ensures strong cellaring potential. Drink 2018–2027.  --->  ['beef', 'fire', 'pot']
#
# Rich honeysuckle, marzipan and oak aromas meet bright lemongrass on the nose of this bottling, showing both the fresh and oxidative sides of the grape. Smoked chicken and brioche notes are prominent on the palate, leading to a tangy, botanical, juniper-laced finish.  --->  ['chicken']
